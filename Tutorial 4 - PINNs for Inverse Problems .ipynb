# %% [markdown]
# ## Physics Informed Neural Networks for Inverse Problems

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import time
import torch.nn as nn
import torch.optim as optim

torch.autograd.set_detect_anomaly(True)
torch.manual_seed(128)

# %% [markdown]
# Consider the one-dimensional heat equation:
#
# $$
# u_t(t, x) = k(t,x)u_{xx}(t, x) + s(t, x), \quad t\in[0,T], ~x\in [-1,1]
# $$
#
# with zero Dirichlet boundary conditions
#
# $$
# u_b(t, -1)=u_b(t,1)=0,
# $$
#
# and initial condition
#
# $$
# u(x, 0) = u_0(x) = - \sin(\pi x)
# $$
#
# The equation parameter $k:[0,T]\times[-1,1]\mapsto \mathbb{R} $ denotes the medium conductivity and $s:[0,T]\times[-1,1]\mapsto \mathbb{R}$ is a source term.

# %% [markdown]
# We want to solve a parameter identification inverse problem, which can be formulated as follows:
#
# Given observation measurements of the medium temperature
#
# $$
# S_{meas}=\{(t_i, x_i, u^{meas}_{i})\}_{i=1}^{N_{meas}},
# $$
# find $u: [0,T]\times[-1,1]\mapsto\mathbb{R}$ and $k:[-1,1]\mapsto \mathbb{R}$, such that
#
# $$u_t(t, x) = k(t,x)u_{xx}(t, x) + s(t,x),
# \\ u_b(t, -1)=u_b(t,1)=0 \quad\text{   and  } \quad u(x, 0) = u_0(x) = -\sin(\pi x).$$

# %% [markdown]
# \\
#
#
# To do so, we approximate the underlying solution and the medium conductivity with two feedforward dense neural network with tunable parameters $\theta$ and $\phi$:
#
# $$
# u_\theta(t,x) \approx u(t,x), \quad k_\phi(t, x) \approx k(t, x)
# $$

# %%
class NeuralNet(nn.Module):

    def __init__(self, input_dimension, output_dimension, n_hidden_layers, neurons, retrain_seed):
        super(NeuralNet, self).__init__()
        # Number of input dimensions n
        self.input_dimension = input_dimension
        # Number of output dimensions m
        self.output_dimension = output_dimension
        # Number of neurons per layer
        self.neurons = neurons
        # Number of hidden layers
        self.n_hidden_layers = n_hidden_layers
        # Activation function
        self.activation = nn.Tanh()

        self.input_layer = nn.Linear(self.input_dimension, self.neurons)
        self.hidden_layers = nn.ModuleList([nn.Linear(self.neurons, self.neurons) for _ in range(n_hidden_layers - 1)])
        self.output_layer = nn.Linear(self.neurons, self.output_dimension)
        self.retrain_seed = retrain_seed
        # Random Seed for weight initialization
        self.init_xavier()

    def forward(self, x):
        # The forward function performs the set of affine and non-linear transformations defining the network
        # (see equation above)
        x = self.activation(self.input_layer(x))
        for k, l in enumerate(self.hidden_layers):
            x = self.activation(l(x))
        return self.output_layer(x)

    def init_xavier(self):
        torch.manual_seed(self.retrain_seed)

        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                torch.nn.init.xavier_uniform_(m.weight, gain=g)
                # torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)

# %% [markdown]
# We define the following residuals:
#
#    - Interior residual given by,
#    $$r_{int,\theta, \phi}(t, x):=  u_{\theta, t}(t, x) - k_\phi(t,x)u_{\theta, xx}(t, x) -s(t,x), \quad \forall ~t \in [0,T],~ x \in [-1,1].$$
#
#
#
#    - Spatial boundary residual given by,
#
#         $$r_{sb,\theta}(t,-1):= u_{\theta}(t,-1)- u_b(t,-1), \quad r_{sb,\theta}(t,1):= u_{\theta}(t,1)- u_b(t,1), \quad \forall t \in (0,T].$$
#
#    - Temporal boundary residual given by,
#
#         $$r_{tb,\theta}(x):= u_{\theta}(x,0) - u_0(x), \quad \forall x \in [-1,1].$$
#
# and compute the corresponding loss functions:
#
# $$
# L_{int}(\theta, \phi) = \int_{[0,T]\times[-1,1]}r_{int,\theta, \phi}^2(t, x) dtdx, \quad
# L_{sb}(\theta) = \int_{[0,T]}r_{sb,\theta}^2(t,-1) dt + \int_{[0,T]}r_{sb,\theta}^2(t,1)dt, \quad
# L_{tb}(\theta) = \int_{[-1,1]}r_{tb,\theta}^2(x) dx
# $$
#
# The loss functions include integrals that can be approximated by suitable quadrature rule. We use quasi Monte-Carlo and accordingly define the following training sets
#
# $$
# S_{int} =\{y_n\}, \quad 1 \leq n \leq N_{int},\quad y_n = (x,t)_n \in D_T,
# $$
#
# $$
# S_{sb, -1} =\{t_n, u_b(t_n,-1) \}, \quad 1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{sb, 1} =\{t_n, u_b(t_n,1) \}, \quad1 \leq n \leq N_{sb}, t_n \in [0,T],
# $$
#
# $$
# S_{tb}=\{x_n, u_0(x_n)\}\quad  1 \leq n \leq N_{tb}, x_n \in [-1,1].
# $$
#
# with the training inputs points corresponding to low-discrepancy Sobol sequences:
#
# $$
# L_{int}(\theta, \phi) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,\theta,\phi}^2(y_n), \quad
# L_{sb}(\theta) = \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,-1) + \frac{1}{N_{sb}}\sum_{i=1}^{N_{sb}}r_{sb,\theta}^2(t_n,1), \quad
# L_{tb}(\theta) = \frac{1}{N_{tb}}\sum_{i=1}^{N_{tb}}r_{tb,\theta}^2(x_n)
# $$
#
# Also the measurements data $S_{meas}$ have to taken into account. To do so, we define ad additional loss term:
# $$
# L_{meas} = \frac{1}{N_{meas}}\sum_{i=1}^{N_{mean}}(u_\theta(t_i, x_i) - u^{meas}_i)^2(x_n)
# $$
# and eventually solve the following minimization problem
#
# $$
# \theta^\ast, \phi^\ast = argmin_{\theta, \phi} \Big(L_{int}(\theta, \phi) + \lambda_u L_u(\theta)\Big)
# $$
#
# with
#
# $$
# L_u(\theta) = L_{tb}(\theta) + L_{sb}(\theta) + L_{meas}(\theta)
# $$

# %% [markdown]
# \\
#
# \\
#
# \\
#
# In the following let us assume
#
# $$u_{ex}(t,x) = -\exp(-\pi^2 t)\sin(\pi x), \quad k(t,x)=k(x)=\sin(\pi x).$$
#
# Then, the source term $s$ can be computed by plugging the expression above in the PDE:
#
# $$
# s(t,x) = -\pi^2u_{ex}(t,x)*(1 - k(t,x))
# $$
#
# Moreover, let us assume that the measurments data are given as follows:
#
# $$
# u_{meas}(x_i, t_i) = u_{ex}(x_i t_i) + 0.01\xi, \quad \xi \sim \mathcal{N(0, 1)}
# $$
#
# where $\mathcal{N(0, 1)}$ is a standard normal distribution.

# %%
# Initial condition to solve the heat equation u0(x)=-sin(pi x)
def initial_condition(x):
    return -torch.sin(np.pi * x)

# Exact solution for the heat equation ut = u_xx with the IC above
def exact_solution(inputs):
    t = inputs[:, 0]
    x = inputs[:, 1]

    u = -torch.exp(-np.pi ** 2 * t) * torch.sin(np.pi * x)
    return u

def exact_conductivity(inputs):
    t = inputs[:, 0]
    x = inputs[:, 1]
    k = (torch.sin(np.pi * x) + 1.1)

    return k


def source(inputs):
    s = -np.pi**2*exact_solution(inputs)*(1 - exact_conductivity(inputs))
    return s

# %%
class Pinns:
    def __init__(self, n_int_, n_sb_, n_tb_):
        self.n_int = n_int_
        self.n_sb = n_sb_
        self.n_tb = n_tb_


        # Extrema of the solution domain (t,x) in [0,0.1] x [-1,1]
        self.domain_extrema = torch.tensor([[0, 0.1],  # Time dimension
                                            [-1, 1]])  # Space dimension

        # Number of space dimensions
        self.space_dimensions = 1

        # Parameter to balance role of data and PDE
        self.lambda_u = 10

        # FF Dense NN to approximate the solution of the underlying heat equation
        self.approximate_solution = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=1,
                                              n_hidden_layers=4,
                                              neurons=20,
                                              retrain_seed=42)

        # FF Dense NN to approximate the conductivity we wish to infer
        self.approximate_coefficient = NeuralNet(input_dimension=self.domain_extrema.shape[0],
                                                 output_dimension=1,
                                                 n_hidden_layers=4,
                                                 neurons=20,
                                                 retrain_seed=42)

        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(dimension=self.domain_extrema.shape[0])

        # Training sets S_sb, S_tb, S_int as torch dataloader
        self.training_set_sb, self.training_set_tb, self.training_set_int = self.assemble_datasets()

        # number of sensors to record temperature
        self.n_sensor = 50

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0]) + self.domain_extrema[:, 0]


    ################################################################################################
    # Function returning the input-output tensor required to assemble the training set S_tb corresponding to the temporal boundary
    def add_temporal_boundary_points(self):
        t0 = self.domain_extrema[0, 0]
        input_tb = self.convert(self.soboleng.draw(self.n_tb))
        input_tb[:, 0] = torch.full(input_tb[:, 0].shape, t0)
        output_tb = initial_condition(input_tb[:, 1]).reshape(-1, 1)

        return input_tb, output_tb

    # Function returning the input-output tensor required to assemble the training set S_sb corresponding to the spatial boundary
    def add_spatial_boundary_points(self):
        x0 = self.domain_extrema[1, 0]
        xL = self.domain_extrema[1, 1]

        input_sb = self.convert(self.soboleng.draw(self.n_sb))

        input_sb_0 = torch.clone(input_sb)
        input_sb_0[:, 1] = torch.full(input_sb_0[:, 1].shape, x0)

        input_sb_L = torch.clone(input_sb)
        input_sb_L[:, 1] = torch.full(input_sb_L[:, 1].shape, xL)

        output_sb_0 = torch.zeros((input_sb.shape[0], 1))
        output_sb_L = torch.zeros((input_sb.shape[0], 1))

        return torch.cat([input_sb_0, input_sb_L], 0), torch.cat([output_sb_0, output_sb_L], 0)

    #  Function returning the input-output tensor required to assemble the training set S_int corresponding to the interior domain where the PDE is enforced
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int


    def get_measurement_data(self):
        torch.random.manual_seed(42)
        # take measurments every 0.001 sec on a set of randomly placed (in space) sensors
        t = torch.linspace(0, self.domain_extrema[0, 1], 25)
        x = torch.linspace(self.domain_extrema[1, 0], self.domain_extrema[1, 1], self.n_sensor)

        #x = torch.rand(self.n_sensor)
        #x = x * (self.domain_extrema[1, 1] - self.domain_extrema[1, 0]) +  self.domain_extrema[1, 0]

        input_meas = torch.cartesian_prod(t, x)

        output_meas = exact_solution(input_meas).reshape(-1,1)
        noise = 0.01*torch.randn_like(output_meas)
        output_meas = output_meas + noise

        return input_meas, output_meas


    # Function returning the training sets S_sb, S_tb, S_int as dataloader
    def assemble_datasets(self):
        input_sb, output_sb = self.add_spatial_boundary_points()  # S_sb
        input_tb, output_tb = self.add_temporal_boundary_points()  # S_tb
        input_int, output_int = self.add_interior_points()  # S_int

        training_set_sb = DataLoader(torch.utils.data.TensorDataset(input_sb, output_sb), batch_size=2 * self.space_dimensions * self.n_sb, shuffle=False)
        training_set_tb = DataLoader(torch.utils.data.TensorDataset(input_tb, output_tb), batch_size=self.n_tb, shuffle=False)
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)

        return training_set_sb, training_set_tb, training_set_int

    ################################################################################################
    # Function to compute the terms required in the definition of the TEMPORAL boundary residual
    def apply_initial_condition(self, input_tb):
        u_pred_tb = self.approximate_solution(input_tb)
        return u_pred_tb

    # Function to compute the terms required in the definition of the SPATIAL boundary residual
    def apply_boundary_conditions(self, input_sb):
        u_pred_sb = self.approximate_solution(input_sb)

        return u_pred_sb


    # Function to compute the PDE residuals
    def compute_pde_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int).reshape(-1,)
        k = self.approximate_coefficient(input_int).reshape(-1,)

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_t = grad_u[:, 0]
        grad_u_x = grad_u[:, 1]
        grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 1]


        s = source(input_int)


        residual = grad_u_t - k*grad_u_xx - s

        return residual.reshape(-1, )

    # Function to compute the total loss (weighted sum of spatial boundary loss, temporal boundary loss and interior loss)
    def compute_loss(self, inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=True):
        u_pred_sb = self.apply_boundary_conditions(inp_train_sb)
        u_pred_tb = self.apply_initial_condition(inp_train_tb)

        inp_train_meas, u_train_meas = self.get_measurement_data()
        u_pred_meas = self.approximate_solution(inp_train_meas)

        assert (u_pred_sb.shape[1] == u_train_sb.shape[1])
        assert (u_pred_tb.shape[1] == u_train_tb.shape[1])
        assert (u_pred_meas.shape[1] == u_train_meas.shape[1])

        r_int = self.compute_pde_residual(inp_train_int)
        r_sb = u_train_sb - u_pred_sb
        r_tb = u_train_tb - u_pred_tb
        r_meas = u_train_meas - u_pred_meas

        loss_sb = torch.mean(abs(r_sb) ** 2)
        loss_tb = torch.mean(abs(r_tb) ** 2)
        loss_int = torch.mean(abs(r_int) ** 2)
        loss_meas = torch.mean(abs(r_meas) ** 2)

        loss_u = loss_sb + loss_tb + loss_meas

        loss = torch.log10(self.lambda_u * loss_u + loss_int)
        if verbose: print("Total loss: ", round(loss.item(), 4), "| PDE Loss: ", round(torch.log10(loss_int).item(), 4), "| Function Loss: ", round(torch.log10(loss_u).item(), 4))

        return loss

# %% [markdown]
# Define *fit* function that takes model, num_epoch and optimizer as an input.
#
# It runs the gradient descent and returns history of the loss computed at each epoch (using closure rule, as below).

# %%
def fit(model, num_epochs, optimizer, verbose=True):
    history = list()

    # Loop over epochs
    for epoch in range(num_epochs):
        if verbose: print("################################ ", epoch, " ################################")

        for j, ((inp_train_sb, u_train_sb), (inp_train_tb, u_train_tb), (inp_train_int, u_train_int)) in enumerate(zip(model.training_set_sb, model.training_set_tb, model.training_set_int)):
            def closure():
                optimizer.zero_grad()
                loss = model.compute_loss(inp_train_sb, u_train_sb, inp_train_tb, u_train_tb, inp_train_int, verbose=verbose)
                loss.backward()

                history.append(loss.item())
                return loss

            optimizer.step(closure=closure)

    print('Final Loss: ', history[-1])

    return history

# %% [markdown]
# Use the code below to plot the exact and the approximate solutions:

# %%
def plotting(model):
      inputs = model.soboleng.draw(100000)
      inputs = model.convert(inputs)

      output = model.approximate_solution(inputs).reshape(-1, )
      exact_output = exact_solution(inputs).reshape(-1, )

      fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
      im1 = axs[0].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=exact_output.detach(), cmap="jet")
      axs[0].set_xlabel("x")
      axs[0].set_ylabel("t")
      plt.colorbar(im1, ax=axs[0])
      axs[0].grid(True, which="both", ls=":")
      im2 = axs[1].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=output.detach(), cmap="jet")
      axs[1].set_xlabel("x")
      axs[1].set_ylabel("t")
      plt.colorbar(im2, ax=axs[1])
      axs[1].grid(True, which="both", ls=":")
      axs[0].set_title("Exact Solution")
      axs[1].set_title("Approximate Solution")

      err = (torch.mean((output - exact_output) ** 2) / torch.mean(exact_output ** 2)) ** 0.5 * 100
      print("L2 Relative Error Norm U: ", err.item(), "%")

      approx_cond = model.approximate_coefficient(inputs).reshape(-1, )
      exact_cond = exact_conductivity(inputs).reshape(-1, )


      fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
      im1 = axs[0].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=exact_cond.detach(), cmap="jet")
      axs[0].set_xlabel("x")
      axs[0].set_ylabel("t")
      plt.colorbar(im1, ax=axs[0])
      axs[0].grid(True, which="both", ls=":")
      im2 = axs[1].scatter(inputs[:, 1].detach(), inputs[:, 0].detach(), c=approx_cond.detach(), cmap="jet")
      axs[1].set_xlabel("x")
      axs[1].set_ylabel("t")
      plt.colorbar(im2, ax=axs[1])
      axs[1].grid(True, which="both", ls=":")
      axs[0].set_title("Exact Conductivity")
      axs[1].set_title("Approximate Conductivity")

      err = (torch.mean((approx_cond - exact_cond) ** 2) / torch.mean(exact_cond ** 2)) ** 0.5 * 100
      print("L2 Relative Error Norm K: ", err.item(), "%")

      plt.show()

# %% [markdown]
# Let us test the code:

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi x)

n_int = 128
n_sb = 64
n_tb = 64

pinn = Pinns(n_int, n_sb, n_tb)

# %%
# Plot the input training points
input_sb_, output_sb_ = pinn.add_spatial_boundary_points()
input_tb_, output_tb_ = pinn.add_temporal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()
input_meas_, output_meas_ = pinn.get_measurement_data()

plt.figure(figsize=(8, 6), dpi=100)
plt.scatter(input_sb_[:, 1].detach().numpy(), input_sb_[:, 0].detach().numpy(), label="Boundary Points")
plt.scatter(input_int_[:, 1].detach().numpy(), input_int_[:, 0].detach().numpy(), label="Interior Points")
plt.scatter(input_tb_[:, 1].detach().numpy(), input_tb_[:, 0].detach().numpy(), label="Initial Points")
plt.scatter(input_meas_[:, 1].detach().numpy(), input_meas_[:, 0].detach().numpy(), label="Sensors Points", marker="*")
plt.xlabel("x")
plt.ylabel("t")
plt.legend()
plt.show()

# %%
n_epochs = 1
max_iter = 1000
optimizer_LBFGS = optim.LBFGS(list(pinn.approximate_solution.parameters()) + list(pinn.approximate_coefficient.parameters()),
                              lr=float(0.5),
                              max_iter=max_iter,
                              max_eval=50000,
                              history_size=150,
                              line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)

optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.005))

# %%
hist = fit(pinn,
          num_epochs=n_epochs,
          optimizer=optimizer_LBFGS,
          verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  -2.4673 | PDE Loss:  -2.9583 | Function Loss:  -3.6366
# Total loss:  0.0559 | PDE Loss:  -0.2297 | Function Loss:  -1.2611
# Total loss:  -2.2686 | PDE Loss:  -2.669 | Function Loss:  -3.4887
# Total loss:  -2.4674 | PDE Loss:  -2.9583 | Function Loss:  -3.6367
# Total loss:  -2.468 | PDE Loss:  -2.9594 | Function Loss:  -3.6371
# Total loss:  -2.4681 | PDE Loss:  -2.9595 | Function Loss:  -3.6372
# Total loss:  -2.4681 | PDE Loss:  -2.9596 | Function Loss:  -3.6372
# Total loss:  -2.4682 | PDE Loss:  -2.96 | Function Loss:  -3.6372
# Total loss:  -2.4685 | PDE Loss:  -2.9606 | Function Loss:  -3.6372
# Total loss:  -2.4687 | PDE Loss:  -2.9616 | Function Loss:  -3.6372
# Total loss:  -2.4691 | PDE Loss:  -2.9629 | Function Loss:  -3.637
# Total loss:  -2.4693 | PDE Loss:  -2.9638 | Function Loss:  -3.637
# Total loss:  -2.4696 | PDE Loss:  -2.9644 | Function Loss:  -3.6371
# Total loss:  -2.4698 | PDE Loss:  -2.965 | Function Loss:  -3.6371
# Total loss:  -2.47 | PDE Loss:  -2.9657 | Function Loss:  -3.6372
# Total loss:  -2.4704 | PDE Loss:  -2.9666 | Function Loss:  -3.6372
# Total loss:  -2.4709 | PDE Loss:  -2.9679 | Function Loss:  -3.6373
# Total loss:  -2.4715 | PDE Loss:  -2.9699 | Function Loss:  -3.6374
# Total loss:  -2.4722 | PDE Loss:  -2.9718 | Function Loss:  -3.6375
# Total loss:  -2.4727 | PDE Loss:  -2.9734 | Function Loss:  -3.6375
# Total loss:  -2.4734 | PDE Loss:  -2.9754 | Function Loss:  -3.6375
# Total loss:  -2.4742 | PDE Loss:  -2.9779 | Function Loss:  -3.6376
# Total loss:  -2.4752 | PDE Loss:  -2.9808 | Function Loss:  -3.6377
# Total loss:  -2.4764 | PDE Loss:  -2.9844 | Function Loss:  -3.6378
# Total loss:  -2.4781 | PDE Loss:  -2.9892 | Function Loss:  -3.6382
# Total loss:  -2.4805 | PDE Loss:  -2.9951 | Function Loss:  -3.6391
# Total loss:  -2.4841 | PDE Loss:  -3.0027 | Function Loss:  -3.6409
# Total loss:  -2.4883 | PDE Loss:  -3.01 | Function Loss:  -3.6437
# Total loss:  -2.4914 | PDE Loss:  -3.0172 | Function Loss:  -3.645
# Total loss:  -2.4943 | PDE Loss:  -3.0248 | Function Loss:  -3.6459
# Total loss:  -2.4963 | PDE Loss:  -3.0314 | Function Loss:  -3.6461
# Total loss:  -2.4978 | PDE Loss:  -3.0366 | Function Loss:  -3.646
# Total loss:  -2.499 | PDE Loss:  -3.0411 | Function Loss:  -3.646
# Total loss:  -2.5005 | PDE Loss:  -3.046 | Function Loss:  -3.6461
# Total loss:  -2.5026 | PDE Loss:  -3.0517 | Function Loss:  -3.6468
# Total loss:  -2.505 | PDE Loss:  -3.0567 | Function Loss:  -3.6482
# Total loss:  -2.5073 | PDE Loss:  -3.0623 | Function Loss:  -3.6492
# Total loss:  -2.5085 | PDE Loss:  -3.064 | Function Loss:  -3.6501
# Total loss:  -2.51 | PDE Loss:  -3.0673 | Function Loss:  -3.6509
# Total loss:  -2.5115 | PDE Loss:  -3.0714 | Function Loss:  -3.6515
# Total loss:  -2.5132 | PDE Loss:  -3.0768 | Function Loss:  -3.6517
# Total loss:  -2.515 | PDE Loss:  -3.0834 | Function Loss:  -3.6518
# Total loss:  -2.517 | PDE Loss:  -3.0905 | Function Loss:  -3.6519
# Total loss:  -2.5185 | PDE Loss:  -3.0959 | Function Loss:  -3.652
# Total loss:  -2.52 | PDE Loss:  -3.101 | Function Loss:  -3.6521
# Total loss:  -2.5211 | PDE Loss:  -3.1051 | Function Loss:  -3.6522
# Total loss:  -2.5217 | PDE Loss:  -3.1078 | Function Loss:  -3.6521
# Total loss:  -2.5222 | PDE Loss:  -3.1099 | Function Loss:  -3.652
# Total loss:  -2.5227 | PDE Loss:  -3.1123 | Function Loss:  -3.6519
# Total loss:  -2.5235 | PDE Loss:  -3.1158 | Function Loss:  -3.6518
# Total loss:  -2.5246 | PDE Loss:  -3.1203 | Function Loss:  -3.6517
# Total loss:  -2.5258 | PDE Loss:  -3.1258 | Function Loss:  -3.6514
# Total loss:  -2.5267 | PDE Loss:  -3.1302 | Function Loss:  -3.6512
# Total loss:  -2.5272 | PDE Loss:  -3.1331 | Function Loss:  -3.6509
# Total loss:  -2.5276 | PDE Loss:  -3.1351 | Function Loss:  -3.6507
# Total loss:  -2.5278 | PDE Loss:  -3.1366 | Function Loss:  -3.6505
# Total loss:  -2.528 | PDE Loss:  -3.1379 | Function Loss:  -3.6504
# Total loss:  -2.5283 | PDE Loss:  -3.1395 | Function Loss:  -3.6502
# Total loss:  -2.5287 | PDE Loss:  -3.1418 | Function Loss:  -3.6501
# Total loss:  -2.5294 | PDE Loss:  -3.1452 | Function Loss:  -3.6499
# Total loss:  -2.5305 | PDE Loss:  -3.1504 | Function Loss:  -3.6497
# Total loss:  -2.532 | PDE Loss:  -3.1574 | Function Loss:  -3.6494
# Total loss:  -2.534 | PDE Loss:  -3.167 | Function Loss:  -3.6491
# Total loss:  -2.5355 | PDE Loss:  -3.1776 | Function Loss:  -3.6479
# Total loss:  -2.5367 | PDE Loss:  -3.1827 | Function Loss:  -3.6479
# Total loss:  -2.5378 | PDE Loss:  -3.1869 | Function Loss:  -3.6481
# Total loss:  -2.5383 | PDE Loss:  -3.1885 | Function Loss:  -3.6483
# Total loss:  -2.5387 | PDE Loss:  -3.1891 | Function Loss:  -3.6486
# Total loss:  -2.539 | PDE Loss:  -3.1893 | Function Loss:  -3.649
# Total loss:  -2.5394 | PDE Loss:  -3.1893 | Function Loss:  -3.6495
# Total loss:  -2.54 | PDE Loss:  -3.1892 | Function Loss:  -3.6503
# Total loss:  -2.5409 | PDE Loss:  -3.1894 | Function Loss:  -3.6514
# Total loss:  -2.5422 | PDE Loss:  -3.1905 | Function Loss:  -3.6528
# Total loss:  -2.544 | PDE Loss:  -3.1928 | Function Loss:  -3.6544
# Total loss:  -2.5457 | PDE Loss:  -3.1955 | Function Loss:  -3.6559
# Total loss:  -2.5469 | PDE Loss:  -3.1981 | Function Loss:  -3.6567
# Total loss:  -2.548 | PDE Loss:  -3.2012 | Function Loss:  -3.6571
# Total loss:  -2.5487 | PDE Loss:  -3.2035 | Function Loss:  -3.6574
# Total loss:  -2.5491 | PDE Loss:  -3.2053 | Function Loss:  -3.6574
# Total loss:  -2.5494 | PDE Loss:  -3.2064 | Function Loss:  -3.6575
# Total loss:  -2.5497 | PDE Loss:  -3.2073 | Function Loss:  -3.6576
# Total loss:  -2.5502 | PDE Loss:  -3.208 | Function Loss:  -3.658
# Total loss:  -2.5512 | PDE Loss:  -3.2092 | Function Loss:  -3.6591
# Total loss:  -2.5531 | PDE Loss:  -3.2097 | Function Loss:  -3.6613
# Total loss:  -2.555 | PDE Loss:  -3.209 | Function Loss:  -3.6639
# Total loss:  -2.5569 | PDE Loss:  -3.207 | Function Loss:  -3.6669
# Total loss:  -2.5583 | PDE Loss:  -3.2044 | Function Loss:  -3.6695
# Total loss:  -2.5595 | PDE Loss:  -3.2018 | Function Loss:  -3.6718
# Total loss:  -2.5605 | PDE Loss:  -3.1991 | Function Loss:  -3.6739
# Total loss:  -2.5613 | PDE Loss:  -3.197 | Function Loss:  -3.6756
# Total loss:  -2.5625 | PDE Loss:  -3.1952 | Function Loss:  -3.6777
# Total loss:  -2.5638 | PDE Loss:  -3.1934 | Function Loss:  -3.6799
# Total loss:  -2.5651 | PDE Loss:  -3.193 | Function Loss:  -3.6817
# Total loss:  -2.5662 | PDE Loss:  -3.1933 | Function Loss:  -3.6831
# Total loss:  -2.5673 | PDE Loss:  -3.1955 | Function Loss:  -3.6839
# Total loss:  -2.5684 | PDE Loss:  -3.1975 | Function Loss:  -3.6846
# Total loss:  -2.5694 | PDE Loss:  -3.1996 | Function Loss:  -3.6854
# Total loss:  -2.5705 | PDE Loss:  -3.201 | Function Loss:  -3.6863
# Total loss:  -2.5716 | PDE Loss:  -3.2027 | Function Loss:  -3.6873
# Total loss:  -2.573 | PDE Loss:  -3.2044 | Function Loss:  -3.6887
# Total loss:  -2.5746 | PDE Loss:  -3.2069 | Function Loss:  -3.6899
# Total loss:  -2.5766 | PDE Loss:  -3.21 | Function Loss:  -3.6916
# Total loss:  -2.5787 | PDE Loss:  -3.2141 | Function Loss:  -3.693
# Total loss:  -2.5808 | PDE Loss:  -3.219 | Function Loss:  -3.6944
# Total loss:  -2.5828 | PDE Loss:  -3.2244 | Function Loss:  -3.6953
# Total loss:  -2.5846 | PDE Loss:  -3.2303 | Function Loss:  -3.6959
# Total loss:  -2.5862 | PDE Loss:  -3.2356 | Function Loss:  -3.6964
# Total loss:  -2.5877 | PDE Loss:  -3.2421 | Function Loss:  -3.6965
# Total loss:  -2.589 | PDE Loss:  -3.2456 | Function Loss:  -3.6972
# Total loss:  -2.5902 | PDE Loss:  -3.2499 | Function Loss:  -3.6975
# Total loss:  -2.5913 | PDE Loss:  -3.2516 | Function Loss:  -3.6985
# Total loss:  -2.5942 | PDE Loss:  -3.2555 | Function Loss:  -3.701
# Total loss:  -2.5993 | PDE Loss:  -3.2612 | Function Loss:  -3.706
# Total loss:  -2.6033 | PDE Loss:  -3.2673 | Function Loss:  -3.7094
# Total loss:  -2.6052 | PDE Loss:  -3.2645 | Function Loss:  -3.7127
# Total loss:  -2.6067 | PDE Loss:  -3.2648 | Function Loss:  -3.7144
# Total loss:  -2.6075 | PDE Loss:  -3.2647 | Function Loss:  -3.7155
# Total loss:  -2.6086 | PDE Loss:  -3.2653 | Function Loss:  -3.7167
# Total loss:  -2.6109 | PDE Loss:  -3.2686 | Function Loss:  -3.7188
# Total loss:  -2.6133 | PDE Loss:  -3.2726 | Function Loss:  -3.7207
# Total loss:  -2.6149 | PDE Loss:  -3.2729 | Function Loss:  -3.7226
# Total loss:  -2.6159 | PDE Loss:  -3.2738 | Function Loss:  -3.7238
# Total loss:  -2.6169 | PDE Loss:  -3.2743 | Function Loss:  -3.7248
# Total loss:  -2.6177 | PDE Loss:  -3.2747 | Function Loss:  -3.7258
# Total loss:  -2.6184 | PDE Loss:  -3.2761 | Function Loss:  -3.7262
# Total loss:  -2.6189 | PDE Loss:  -3.2768 | Function Loss:  -3.7267
# Total loss:  -2.6194 | PDE Loss:  -3.279 | Function Loss:  -3.7268
# Total loss:  -2.62 | PDE Loss:  -3.2811 | Function Loss:  -3.7269
# Total loss:  -2.6208 | PDE Loss:  -3.2843 | Function Loss:  -3.7271
# Total loss:  -2.6216 | PDE Loss:  -3.2873 | Function Loss:  -3.7273
# Total loss:  -2.6225 | PDE Loss:  -3.2902 | Function Loss:  -3.7276
# Total loss:  -2.6235 | PDE Loss:  -3.2932 | Function Loss:  -3.728
# Total loss:  -2.6244 | PDE Loss:  -3.2964 | Function Loss:  -3.7284
# Total loss:  -2.6255 | PDE Loss:  -3.2996 | Function Loss:  -3.7288
# Total loss:  -2.6268 | PDE Loss:  -3.3034 | Function Loss:  -3.7295
# Total loss:  -2.6286 | PDE Loss:  -3.3078 | Function Loss:  -3.7306
# Total loss:  -2.6313 | PDE Loss:  -3.313 | Function Loss:  -3.7327
# Total loss:  -2.6352 | PDE Loss:  -3.3178 | Function Loss:  -3.7363
# Total loss:  -2.6401 | PDE Loss:  -3.3207 | Function Loss:  -3.7417
# Total loss:  -2.646 | PDE Loss:  -3.3205 | Function Loss:  -3.7493
# Total loss:  -2.6531 | PDE Loss:  -3.3174 | Function Loss:  -3.7591
# Total loss:  -2.6606 | PDE Loss:  -3.3145 | Function Loss:  -3.7695
# Total loss:  -2.6648 | PDE Loss:  -3.3004 | Function Loss:  -3.7791
# Total loss:  -2.6692 | PDE Loss:  -3.3051 | Function Loss:  -3.7834
# Total loss:  -2.6708 | PDE Loss:  -3.3078 | Function Loss:  -3.7848
# Total loss:  -2.6719 | PDE Loss:  -3.3089 | Function Loss:  -3.7858
# Total loss:  -2.6727 | PDE Loss:  -3.3088 | Function Loss:  -3.7869
# Total loss:  -2.6735 | PDE Loss:  -3.3076 | Function Loss:  -3.7883
# Total loss:  -2.6743 | PDE Loss:  -3.3048 | Function Loss:  -3.7901
# Total loss:  -2.675 | PDE Loss:  -3.3011 | Function Loss:  -3.7921
# Total loss:  -2.6755 | PDE Loss:  -3.2969 | Function Loss:  -3.7942
# Total loss:  -2.676 | PDE Loss:  -3.2932 | Function Loss:  -3.7959
# Total loss:  -2.6763 | PDE Loss:  -3.2897 | Function Loss:  -3.7976
# Total loss:  -2.6768 | PDE Loss:  -3.2863 | Function Loss:  -3.7992
# Total loss:  -2.6776 | PDE Loss:  -3.2826 | Function Loss:  -3.8016
# Total loss:  -2.6793 | PDE Loss:  -3.2772 | Function Loss:  -3.8057
# Total loss:  -2.6808 | PDE Loss:  -3.2695 | Function Loss:  -3.8103
# Total loss:  -2.6834 | PDE Loss:  -3.2664 | Function Loss:  -3.8149
# Total loss:  -2.6864 | PDE Loss:  -3.2674 | Function Loss:  -3.8186
# Total loss:  -2.6896 | PDE Loss:  -3.2632 | Function Loss:  -3.8245
# Total loss:  -2.6934 | PDE Loss:  -3.2748 | Function Loss:  -3.8254
# Total loss:  -2.6966 | PDE Loss:  -3.2885 | Function Loss:  -3.825
# Total loss:  -2.7002 | PDE Loss:  -3.3078 | Function Loss:  -3.8233
# Total loss:  -2.7022 | PDE Loss:  -3.3201 | Function Loss:  -3.8219
# Total loss:  -2.703 | PDE Loss:  -3.3252 | Function Loss:  -3.8214
# Total loss:  -2.7035 | PDE Loss:  -3.3266 | Function Loss:  -3.8217
# Total loss:  -2.704 | PDE Loss:  -3.3258 | Function Loss:  -3.8226
# Total loss:  -2.7044 | PDE Loss:  -3.3233 | Function Loss:  -3.8238
# Total loss:  -2.7046 | PDE Loss:  -3.3195 | Function Loss:  -3.8254
# Total loss:  -2.7048 | PDE Loss:  -3.3169 | Function Loss:  -3.8264
# Total loss:  -2.7049 | PDE Loss:  -3.3143 | Function Loss:  -3.8275
# Total loss:  -2.7051 | PDE Loss:  -3.311 | Function Loss:  -3.8288
# Total loss:  -2.7054 | PDE Loss:  -3.3075 | Function Loss:  -3.8303
# Total loss:  -2.7058 | PDE Loss:  -3.3033 | Function Loss:  -3.8323
# Total loss:  -2.7065 | PDE Loss:  -3.2985 | Function Loss:  -3.8349
# Total loss:  -2.7076 | PDE Loss:  -3.2928 | Function Loss:  -3.8383
# Total loss:  -2.7092 | PDE Loss:  -3.2865 | Function Loss:  -3.8428
# Total loss:  -2.7112 | PDE Loss:  -3.283 | Function Loss:  -3.8467
# Total loss:  -2.7131 | PDE Loss:  -3.279 | Function Loss:  -3.8508
# Total loss:  -2.7147 | PDE Loss:  -3.2802 | Function Loss:  -3.8526
# Total loss:  -2.7154 | PDE Loss:  -3.2761 | Function Loss:  -3.855
# Total loss:  -2.716 | PDE Loss:  -3.278 | Function Loss:  -3.8552
# Total loss:  -2.7162 | PDE Loss:  -3.2794 | Function Loss:  -3.8549
# Total loss:  -2.7164 | PDE Loss:  -3.2808 | Function Loss:  -3.8547
# Total loss:  -2.7166 | PDE Loss:  -3.2823 | Function Loss:  -3.8544
# Total loss:  -2.7168 | PDE Loss:  -3.2835 | Function Loss:  -3.8542
# Total loss:  -2.7171 | PDE Loss:  -3.2846 | Function Loss:  -3.8542
# Total loss:  -2.7174 | PDE Loss:  -3.2849 | Function Loss:  -3.8545
# Total loss:  -2.7179 | PDE Loss:  -3.2845 | Function Loss:  -3.8553
# Total loss:  -2.7186 | PDE Loss:  -3.283 | Function Loss:  -3.8568
# Total loss:  -2.7196 | PDE Loss:  -3.2802 | Function Loss:  -3.8592
# Total loss:  -2.7208 | PDE Loss:  -3.2772 | Function Loss:  -3.8621
# Total loss:  -2.7224 | PDE Loss:  -3.2732 | Function Loss:  -3.8659
# Total loss:  -2.7244 | PDE Loss:  -3.2687 | Function Loss:  -3.8705
# Total loss:  -2.7251 | PDE Loss:  -3.2621 | Function Loss:  -3.8741
# Total loss:  -2.7281 | PDE Loss:  -3.2651 | Function Loss:  -3.877
# Total loss:  -2.7311 | PDE Loss:  -3.2699 | Function Loss:  -3.8793
# Total loss:  -2.7355 | PDE Loss:  -3.2742 | Function Loss:  -3.8838
# Total loss:  -2.7402 | PDE Loss:  -3.2845 | Function Loss:  -3.8862
# Total loss:  -2.7425 | PDE Loss:  -3.2898 | Function Loss:  -3.8873
# Total loss:  -2.7449 | PDE Loss:  -3.2976 | Function Loss:  -3.8876
# Total loss:  -2.7459 | PDE Loss:  -3.3023 | Function Loss:  -3.8873
# Total loss:  -2.747 | PDE Loss:  -3.3056 | Function Loss:  -3.8875
# Total loss:  -2.748 | PDE Loss:  -3.3086 | Function Loss:  -3.8877
# Total loss:  -2.7491 | PDE Loss:  -3.3106 | Function Loss:  -3.8884
# Total loss:  -2.7501 | PDE Loss:  -3.3139 | Function Loss:  -3.8886
# Total loss:  -2.7507 | PDE Loss:  -3.3158 | Function Loss:  -3.8887
# Total loss:  -2.7514 | PDE Loss:  -3.3171 | Function Loss:  -3.8891
# Total loss:  -2.7518 | PDE Loss:  -3.3186 | Function Loss:  -3.8892
# Total loss:  -2.7522 | PDE Loss:  -3.3197 | Function Loss:  -3.8893
# Total loss:  -2.7526 | PDE Loss:  -3.3215 | Function Loss:  -3.8892
# Total loss:  -2.753 | PDE Loss:  -3.3231 | Function Loss:  -3.8892
# Total loss:  -2.7536 | PDE Loss:  -3.3254 | Function Loss:  -3.8891
# Total loss:  -2.7546 | PDE Loss:  -3.3296 | Function Loss:  -3.889
# Total loss:  -2.7564 | PDE Loss:  -3.3357 | Function Loss:  -3.8892
# Total loss:  -2.7586 | PDE Loss:  -3.3439 | Function Loss:  -3.8893
# Total loss:  -2.7612 | PDE Loss:  -3.3498 | Function Loss:  -3.8907
# Total loss:  -2.7636 | PDE Loss:  -3.357 | Function Loss:  -3.8915
# Total loss:  -2.7655 | PDE Loss:  -3.3607 | Function Loss:  -3.8928
# Total loss:  -2.767 | PDE Loss:  -3.3632 | Function Loss:  -3.8939
# Total loss:  -2.7679 | PDE Loss:  -3.3657 | Function Loss:  -3.8943
# Total loss:  -2.7684 | PDE Loss:  -3.3678 | Function Loss:  -3.8942
# Total loss:  -2.769 | PDE Loss:  -3.3709 | Function Loss:  -3.894
# Total loss:  -2.7698 | PDE Loss:  -3.3766 | Function Loss:  -3.8932
# Total loss:  -2.7706 | PDE Loss:  -3.3831 | Function Loss:  -3.8922
# Total loss:  -2.7715 | PDE Loss:  -3.3903 | Function Loss:  -3.8909
# Total loss:  -2.7723 | PDE Loss:  -3.3978 | Function Loss:  -3.8897
# Total loss:  -2.7732 | PDE Loss:  -3.4058 | Function Loss:  -3.8884
# Total loss:  -2.7742 | PDE Loss:  -3.414 | Function Loss:  -3.8873
# Total loss:  -2.7754 | PDE Loss:  -3.4221 | Function Loss:  -3.8864
# Total loss:  -2.7766 | PDE Loss:  -3.4299 | Function Loss:  -3.8858
# Total loss:  -2.778 | PDE Loss:  -3.4373 | Function Loss:  -3.8855
# Total loss:  -2.7796 | PDE Loss:  -3.4443 | Function Loss:  -3.8855
# Total loss:  -2.7811 | PDE Loss:  -3.4492 | Function Loss:  -3.8861
# Total loss:  -2.7822 | PDE Loss:  -3.4527 | Function Loss:  -3.8865
# Total loss:  -2.7828 | PDE Loss:  -3.4536 | Function Loss:  -3.8871
# Total loss:  -2.7833 | PDE Loss:  -3.455 | Function Loss:  -3.8873
# Total loss:  -2.7837 | PDE Loss:  -3.4566 | Function Loss:  -3.8874
# Total loss:  -2.7841 | PDE Loss:  -3.4584 | Function Loss:  -3.8875
# Total loss:  -2.7846 | PDE Loss:  -3.4606 | Function Loss:  -3.8874
# Total loss:  -2.7852 | PDE Loss:  -3.4631 | Function Loss:  -3.8875
# Total loss:  -2.786 | PDE Loss:  -3.4665 | Function Loss:  -3.8876
# Total loss:  -2.7871 | PDE Loss:  -3.4706 | Function Loss:  -3.888
# Total loss:  -2.7887 | PDE Loss:  -3.4757 | Function Loss:  -3.8886
# Total loss:  -2.7907 | PDE Loss:  -3.4815 | Function Loss:  -3.8896
# Total loss:  -2.7932 | PDE Loss:  -3.4881 | Function Loss:  -3.8911
# Total loss:  -2.7962 | PDE Loss:  -3.4947 | Function Loss:  -3.8932
# Total loss:  -2.7989 | PDE Loss:  -3.5011 | Function Loss:  -3.895
# Total loss:  -2.8007 | PDE Loss:  -3.502 | Function Loss:  -3.8971
# Total loss:  -2.8017 | PDE Loss:  -3.502 | Function Loss:  -3.8983
# Total loss:  -2.8024 | PDE Loss:  -3.5011 | Function Loss:  -3.8993
# Total loss:  -2.8029 | PDE Loss:  -3.4999 | Function Loss:  -3.9003
# Total loss:  -2.8033 | PDE Loss:  -3.4993 | Function Loss:  -3.901
# Total loss:  -2.8036 | PDE Loss:  -3.4989 | Function Loss:  -3.9014
# Total loss:  -2.8038 | PDE Loss:  -3.4991 | Function Loss:  -3.9017
# Total loss:  -2.804 | PDE Loss:  -3.4999 | Function Loss:  -3.9016
# Total loss:  -2.8041 | PDE Loss:  -3.5009 | Function Loss:  -3.9015
# Total loss:  -2.8042 | PDE Loss:  -3.5019 | Function Loss:  -3.9014
# Total loss:  -2.8043 | PDE Loss:  -3.5027 | Function Loss:  -3.9013
# Total loss:  -2.8045 | PDE Loss:  -3.504 | Function Loss:  -3.9013
# Total loss:  -2.8048 | PDE Loss:  -3.5048 | Function Loss:  -3.9014
# Total loss:  -2.8052 | PDE Loss:  -3.5058 | Function Loss:  -3.9017
# Total loss:  -2.8057 | PDE Loss:  -3.5062 | Function Loss:  -3.9023
# Total loss:  -2.8064 | PDE Loss:  -3.5057 | Function Loss:  -3.9032
# Total loss:  -2.807 | PDE Loss:  -3.5051 | Function Loss:  -3.9041
# Total loss:  -2.8077 | PDE Loss:  -3.504 | Function Loss:  -3.9053
# Total loss:  -2.8084 | PDE Loss:  -3.5041 | Function Loss:  -3.9061
# Total loss:  -2.8089 | PDE Loss:  -3.5037 | Function Loss:  -3.9069
# Total loss:  -2.8095 | PDE Loss:  -3.5034 | Function Loss:  -3.9077
# Total loss:  -2.8103 | PDE Loss:  -3.5042 | Function Loss:  -3.9085
# Total loss:  -2.8112 | PDE Loss:  -3.5064 | Function Loss:  -3.9091
# Total loss:  -2.8119 | PDE Loss:  -3.5091 | Function Loss:  -3.9093
# Total loss:  -2.8124 | PDE Loss:  -3.5117 | Function Loss:  -3.9092
# Total loss:  -2.8127 | PDE Loss:  -3.5142 | Function Loss:  -3.909
# Total loss:  -2.8129 | PDE Loss:  -3.5162 | Function Loss:  -3.9088
# Total loss:  -2.8131 | PDE Loss:  -3.5177 | Function Loss:  -3.9086
# Total loss:  -2.8132 | PDE Loss:  -3.5186 | Function Loss:  -3.9085
# Total loss:  -2.8133 | PDE Loss:  -3.5201 | Function Loss:  -3.9083
# Total loss:  -2.8134 | PDE Loss:  -3.521 | Function Loss:  -3.9082
# Total loss:  -2.8136 | PDE Loss:  -3.5223 | Function Loss:  -3.9081
# Total loss:  -2.8139 | PDE Loss:  -3.5235 | Function Loss:  -3.9082
# Total loss:  -2.8144 | PDE Loss:  -3.5251 | Function Loss:  -3.9084
# Total loss:  -2.815 | PDE Loss:  -3.5265 | Function Loss:  -3.9089
# Total loss:  -2.8161 | PDE Loss:  -3.5283 | Function Loss:  -3.9097
# Total loss:  -2.8175 | PDE Loss:  -3.5303 | Function Loss:  -3.9111
# Total loss:  -2.8195 | PDE Loss:  -3.5327 | Function Loss:  -3.9129
# Total loss:  -2.8219 | PDE Loss:  -3.536 | Function Loss:  -3.9151
# Total loss:  -2.8244 | PDE Loss:  -3.5389 | Function Loss:  -3.9176
# Total loss:  -2.8268 | PDE Loss:  -3.5429 | Function Loss:  -3.9195
# Total loss:  -2.8294 | PDE Loss:  -3.5495 | Function Loss:  -3.9212
# Total loss:  -2.832 | PDE Loss:  -3.5569 | Function Loss:  -3.9226
# Total loss:  -2.8341 | PDE Loss:  -3.5639 | Function Loss:  -3.9236
# Total loss:  -2.8336 | PDE Loss:  -3.5571 | Function Loss:  -3.9246
# Total loss:  -2.8349 | PDE Loss:  -3.5653 | Function Loss:  -3.9242
# Total loss:  -2.8362 | PDE Loss:  -3.5703 | Function Loss:  -3.9247
# Total loss:  -2.8367 | PDE Loss:  -3.5704 | Function Loss:  -3.9254
# Total loss:  -2.8371 | PDE Loss:  -3.5709 | Function Loss:  -3.9257
# Total loss:  -2.8374 | PDE Loss:  -3.5707 | Function Loss:  -3.9262
# Total loss:  -2.8376 | PDE Loss:  -3.5701 | Function Loss:  -3.9266
# Total loss:  -2.8378 | PDE Loss:  -3.57 | Function Loss:  -3.9268
# Total loss:  -2.8379 | PDE Loss:  -3.5687 | Function Loss:  -3.9272
# Total loss:  -2.838 | PDE Loss:  -3.5682 | Function Loss:  -3.9275
# Total loss:  -2.8381 | PDE Loss:  -3.5678 | Function Loss:  -3.9276
# Total loss:  -2.8382 | PDE Loss:  -3.5673 | Function Loss:  -3.9279
# Total loss:  -2.8383 | PDE Loss:  -3.567 | Function Loss:  -3.9281
# Total loss:  -2.8385 | PDE Loss:  -3.5667 | Function Loss:  -3.9284
# Total loss:  -2.8387 | PDE Loss:  -3.5665 | Function Loss:  -3.9287
# Total loss:  -2.8389 | PDE Loss:  -3.5669 | Function Loss:  -3.9289
# Total loss:  -2.8394 | PDE Loss:  -3.5673 | Function Loss:  -3.9294
# Total loss:  -2.8402 | PDE Loss:  -3.5683 | Function Loss:  -3.9302
# Total loss:  -2.8412 | PDE Loss:  -3.5689 | Function Loss:  -3.9313
# Total loss:  -2.8428 | PDE Loss:  -3.5711 | Function Loss:  -3.9327
# Total loss:  -2.844 | PDE Loss:  -3.5718 | Function Loss:  -3.934
# Total loss:  -2.8461 | PDE Loss:  -3.5748 | Function Loss:  -3.9359
# Total loss:  -2.8478 | PDE Loss:  -3.577 | Function Loss:  -3.9375
# Total loss:  -2.8498 | PDE Loss:  -3.58 | Function Loss:  -3.9392
# Total loss:  -2.8508 | PDE Loss:  -3.5812 | Function Loss:  -3.9403
# Total loss:  -2.8518 | PDE Loss:  -3.5827 | Function Loss:  -3.9411
# Total loss:  -2.853 | PDE Loss:  -3.5844 | Function Loss:  -3.9421
# Total loss:  -2.854 | PDE Loss:  -3.586 | Function Loss:  -3.943
# Total loss:  -2.8552 | PDE Loss:  -3.5905 | Function Loss:  -3.9435
# Total loss:  -2.8561 | PDE Loss:  -3.5942 | Function Loss:  -3.9438
# Total loss:  -2.8571 | PDE Loss:  -3.5957 | Function Loss:  -3.9446
# Total loss:  -2.8577 | PDE Loss:  -3.5986 | Function Loss:  -3.9447
# Total loss:  -2.8581 | PDE Loss:  -3.6 | Function Loss:  -3.9449
# Total loss:  -2.8587 | PDE Loss:  -3.6021 | Function Loss:  -3.9452
# Total loss:  -2.8593 | PDE Loss:  -3.6037 | Function Loss:  -3.9456
# Total loss:  -2.8599 | PDE Loss:  -3.606 | Function Loss:  -3.9457
# Total loss:  -2.8604 | PDE Loss:  -3.6075 | Function Loss:  -3.946
# Total loss:  -2.8609 | PDE Loss:  -3.6106 | Function Loss:  -3.946
# Total loss:  -2.8613 | PDE Loss:  -3.6136 | Function Loss:  -3.9459
# Total loss:  -2.8618 | PDE Loss:  -3.6175 | Function Loss:  -3.9456
# Total loss:  -2.8622 | PDE Loss:  -3.6226 | Function Loss:  -3.9451
# Total loss:  -2.8626 | PDE Loss:  -3.6258 | Function Loss:  -3.9448
# Total loss:  -2.8631 | PDE Loss:  -3.632 | Function Loss:  -3.9441
# Total loss:  -2.8635 | PDE Loss:  -3.6382 | Function Loss:  -3.9434
# Total loss:  -2.8638 | PDE Loss:  -3.6424 | Function Loss:  -3.9429
# Total loss:  -2.8641 | PDE Loss:  -3.6468 | Function Loss:  -3.9424
# Total loss:  -2.8643 | PDE Loss:  -3.6495 | Function Loss:  -3.942
# Total loss:  -2.8644 | PDE Loss:  -3.6516 | Function Loss:  -3.9418
# Total loss:  -2.8644 | PDE Loss:  -3.6529 | Function Loss:  -3.9416
# Total loss:  -2.8645 | PDE Loss:  -3.6542 | Function Loss:  -3.9414
# Total loss:  -2.8646 | PDE Loss:  -3.6558 | Function Loss:  -3.9412
# Total loss:  -2.8646 | PDE Loss:  -3.6566 | Function Loss:  -3.9411
# Total loss:  -2.8647 | PDE Loss:  -3.6574 | Function Loss:  -3.9411
# Total loss:  -2.8649 | PDE Loss:  -3.6584 | Function Loss:  -3.9411
# Total loss:  -2.865 | PDE Loss:  -3.6592 | Function Loss:  -3.9411
# Total loss:  -2.8652 | PDE Loss:  -3.6599 | Function Loss:  -3.9412
# Total loss:  -2.8655 | PDE Loss:  -3.6608 | Function Loss:  -3.9413
# Total loss:  -2.8659 | PDE Loss:  -3.6619 | Function Loss:  -3.9415
# Total loss:  -2.8664 | PDE Loss:  -3.6636 | Function Loss:  -3.9419
# Total loss:  -2.8673 | PDE Loss:  -3.6662 | Function Loss:  -3.9424
# Total loss:  -2.8684 | PDE Loss:  -3.6695 | Function Loss:  -3.9431
# Total loss:  -2.8697 | PDE Loss:  -3.6732 | Function Loss:  -3.944
# Total loss:  -2.8711 | PDE Loss:  -3.677 | Function Loss:  -3.9449
# Total loss:  -2.8724 | PDE Loss:  -3.6806 | Function Loss:  -3.9458
# Total loss:  -2.8735 | PDE Loss:  -3.684 | Function Loss:  -3.9464
# Total loss:  -2.8743 | PDE Loss:  -3.6843 | Function Loss:  -3.9473
# Total loss:  -2.8748 | PDE Loss:  -3.6868 | Function Loss:  -3.9475
# Total loss:  -2.8756 | PDE Loss:  -3.6881 | Function Loss:  -3.9483
# Total loss:  -2.8764 | PDE Loss:  -3.691 | Function Loss:  -3.9487
# Total loss:  -2.8773 | PDE Loss:  -3.6919 | Function Loss:  -3.9495
# Total loss:  -2.8784 | PDE Loss:  -3.6931 | Function Loss:  -3.9506
# Total loss:  -2.8797 | PDE Loss:  -3.6942 | Function Loss:  -3.952
# Total loss:  -2.8811 | PDE Loss:  -3.6924 | Function Loss:  -3.954
# Total loss:  -2.8823 | PDE Loss:  -3.6925 | Function Loss:  -3.9553
# Total loss:  -2.8835 | PDE Loss:  -3.6932 | Function Loss:  -3.9566
# Total loss:  -2.8844 | PDE Loss:  -3.6906 | Function Loss:  -3.9581
# Total loss:  -2.8851 | PDE Loss:  -3.689 | Function Loss:  -3.9593
# Total loss:  -2.8855 | PDE Loss:  -3.6865 | Function Loss:  -3.9602
# Total loss:  -2.8857 | PDE Loss:  -3.6851 | Function Loss:  -3.9607
# Total loss:  -2.8858 | PDE Loss:  -3.6839 | Function Loss:  -3.9611
# Total loss:  -2.8859 | PDE Loss:  -3.6833 | Function Loss:  -3.9613
# Total loss:  -2.8859 | PDE Loss:  -3.6829 | Function Loss:  -3.9615
# Total loss:  -2.886 | PDE Loss:  -3.6825 | Function Loss:  -3.9616
# Total loss:  -2.886 | PDE Loss:  -3.6819 | Function Loss:  -3.9617
# Total loss:  -2.886 | PDE Loss:  -3.6814 | Function Loss:  -3.9619
# Total loss:  -2.8861 | PDE Loss:  -3.6807 | Function Loss:  -3.962
# Total loss:  -2.8861 | PDE Loss:  -3.6799 | Function Loss:  -3.9622
# Total loss:  -2.8861 | PDE Loss:  -3.6789 | Function Loss:  -3.9624
# Total loss:  -2.8862 | PDE Loss:  -3.6777 | Function Loss:  -3.9627
# Total loss:  -2.8862 | PDE Loss:  -3.676 | Function Loss:  -3.9631
# Total loss:  -2.8863 | PDE Loss:  -3.6747 | Function Loss:  -3.9635
# Total loss:  -2.8864 | PDE Loss:  -3.6731 | Function Loss:  -3.9639
# Total loss:  -2.8865 | PDE Loss:  -3.6721 | Function Loss:  -3.9642
# Total loss:  -2.8866 | PDE Loss:  -3.6708 | Function Loss:  -3.9646
# Total loss:  -2.8868 | PDE Loss:  -3.6701 | Function Loss:  -3.9649
# Total loss:  -2.887 | PDE Loss:  -3.6694 | Function Loss:  -3.9654
# Total loss:  -2.8874 | PDE Loss:  -3.6698 | Function Loss:  -3.9658
# Total loss:  -2.8879 | PDE Loss:  -3.6694 | Function Loss:  -3.9665
# Total loss:  -2.8886 | PDE Loss:  -3.6715 | Function Loss:  -3.9669
# Total loss:  -2.8898 | PDE Loss:  -3.6741 | Function Loss:  -3.9678
# Total loss:  -2.8918 | PDE Loss:  -3.6824 | Function Loss:  -3.9686
# Total loss:  -2.8939 | PDE Loss:  -3.6896 | Function Loss:  -3.9697
# Total loss:  -2.8959 | PDE Loss:  -3.7023 | Function Loss:  -3.9697
# Total loss:  -2.8906 | PDE Loss:  -3.6683 | Function Loss:  -3.9699
# Total loss:  -2.8971 | PDE Loss:  -3.7051 | Function Loss:  -3.9706
# Total loss:  -2.8987 | PDE Loss:  -3.7128 | Function Loss:  -3.971
# Total loss:  -2.9005 | PDE Loss:  -3.7199 | Function Loss:  -3.9718
# Total loss:  -2.901 | PDE Loss:  -3.73 | Function Loss:  -3.9707
# Total loss:  -2.9021 | PDE Loss:  -3.7309 | Function Loss:  -3.9719
# Total loss:  -2.903 | PDE Loss:  -3.7314 | Function Loss:  -3.9728
# Total loss:  -2.9037 | PDE Loss:  -3.7328 | Function Loss:  -3.9734
# Total loss:  -2.905 | PDE Loss:  -3.7368 | Function Loss:  -3.9742
# Total loss:  -2.9062 | PDE Loss:  -3.7408 | Function Loss:  -3.975
# Total loss:  -2.9072 | PDE Loss:  -3.7456 | Function Loss:  -3.9753
# Total loss:  -2.908 | PDE Loss:  -3.7483 | Function Loss:  -3.9758
# Total loss:  -2.9089 | PDE Loss:  -3.7547 | Function Loss:  -3.9757
# Total loss:  -2.9096 | PDE Loss:  -3.7582 | Function Loss:  -3.976
# Total loss:  -2.9102 | PDE Loss:  -3.7624 | Function Loss:  -3.976
# Total loss:  -2.9109 | PDE Loss:  -3.7687 | Function Loss:  -3.9758
# Total loss:  -2.9116 | PDE Loss:  -3.7759 | Function Loss:  -3.9754
# Total loss:  -2.9121 | PDE Loss:  -3.7807 | Function Loss:  -3.9753
# Total loss:  -2.9125 | PDE Loss:  -3.785 | Function Loss:  -3.975
# Total loss:  -2.9128 | PDE Loss:  -3.7874 | Function Loss:  -3.975
# Total loss:  -2.9131 | PDE Loss:  -3.789 | Function Loss:  -3.9751
# Total loss:  -2.9134 | PDE Loss:  -3.7914 | Function Loss:  -3.9751
# Total loss:  -2.9138 | PDE Loss:  -3.7926 | Function Loss:  -3.9754
# Total loss:  -2.9141 | PDE Loss:  -3.7941 | Function Loss:  -3.9755
# Total loss:  -2.9145 | PDE Loss:  -3.7953 | Function Loss:  -3.9757
# Total loss:  -2.9148 | PDE Loss:  -3.7966 | Function Loss:  -3.9759
# Total loss:  -2.9151 | PDE Loss:  -3.7973 | Function Loss:  -3.9762
# Total loss:  -2.9154 | PDE Loss:  -3.7983 | Function Loss:  -3.9763
# Total loss:  -2.9156 | PDE Loss:  -3.7993 | Function Loss:  -3.9765
# Total loss:  -2.9159 | PDE Loss:  -3.801 | Function Loss:  -3.9766
# Total loss:  -2.9162 | PDE Loss:  -3.8023 | Function Loss:  -3.9767
# Total loss:  -2.9166 | PDE Loss:  -3.8045 | Function Loss:  -3.9768
# Total loss:  -2.917 | PDE Loss:  -3.8059 | Function Loss:  -3.9771
# Total loss:  -2.9173 | PDE Loss:  -3.8081 | Function Loss:  -3.9771
# Total loss:  -2.9175 | PDE Loss:  -3.8094 | Function Loss:  -3.9771
# Total loss:  -2.9177 | PDE Loss:  -3.8112 | Function Loss:  -3.9771
# Total loss:  -2.9179 | PDE Loss:  -3.8123 | Function Loss:  -3.9772
# Total loss:  -2.9181 | PDE Loss:  -3.8128 | Function Loss:  -3.9773
# Total loss:  -2.9182 | PDE Loss:  -3.8132 | Function Loss:  -3.9774
# Total loss:  -2.9183 | PDE Loss:  -3.8131 | Function Loss:  -3.9775
# Total loss:  -2.9185 | PDE Loss:  -3.8128 | Function Loss:  -3.9777
# Total loss:  -2.9186 | PDE Loss:  -3.8123 | Function Loss:  -3.9779
# Total loss:  -2.9187 | PDE Loss:  -3.812 | Function Loss:  -3.9781
# Total loss:  -2.9188 | PDE Loss:  -3.8117 | Function Loss:  -3.9782
# Total loss:  -2.9189 | PDE Loss:  -3.8118 | Function Loss:  -3.9783
# Total loss:  -2.919 | PDE Loss:  -3.8121 | Function Loss:  -3.9784
# Total loss:  -2.9191 | PDE Loss:  -3.8129 | Function Loss:  -3.9785
# Total loss:  -2.9193 | PDE Loss:  -3.8139 | Function Loss:  -3.9785
# Total loss:  -2.9194 | PDE Loss:  -3.8149 | Function Loss:  -3.9785
# Total loss:  -2.9196 | PDE Loss:  -3.8163 | Function Loss:  -3.9785
# Total loss:  -2.9197 | PDE Loss:  -3.8177 | Function Loss:  -3.9785
# Total loss:  -2.92 | PDE Loss:  -3.8199 | Function Loss:  -3.9784
# Total loss:  -2.9203 | PDE Loss:  -3.8236 | Function Loss:  -3.9783
# Total loss:  -2.9209 | PDE Loss:  -3.8288 | Function Loss:  -3.9782
# Total loss:  -2.9215 | PDE Loss:  -3.8354 | Function Loss:  -3.978
# Total loss:  -2.9222 | PDE Loss:  -3.8426 | Function Loss:  -3.9778
# Total loss:  -2.923 | PDE Loss:  -3.8499 | Function Loss:  -3.9777
# Total loss:  -2.9239 | PDE Loss:  -3.8571 | Function Loss:  -3.9778
# Total loss:  -2.9247 | PDE Loss:  -3.8634 | Function Loss:  -3.9779
# Total loss:  -2.9254 | PDE Loss:  -3.8683 | Function Loss:  -3.978
# Total loss:  -2.9258 | PDE Loss:  -3.8709 | Function Loss:  -3.9781
# Total loss:  -2.9262 | PDE Loss:  -3.8754 | Function Loss:  -3.978
# Total loss:  -2.9266 | PDE Loss:  -3.878 | Function Loss:  -3.9781
# Total loss:  -2.9268 | PDE Loss:  -3.8793 | Function Loss:  -3.9782
# Total loss:  -2.9269 | PDE Loss:  -3.8796 | Function Loss:  -3.9783
# Total loss:  -2.927 | PDE Loss:  -3.8797 | Function Loss:  -3.9783
# Total loss:  -2.927 | PDE Loss:  -3.8797 | Function Loss:  -3.9783
# Total loss:  -2.927 | PDE Loss:  -3.8797 | Function Loss:  -3.9784
# Total loss:  -2.927 | PDE Loss:  -3.8797 | Function Loss:  -3.9784
# Total loss:  -2.927 | PDE Loss:  -3.8797 | Function Loss:  -3.9784
# Total loss:  -2.927 | PDE Loss:  -3.8798 | Function Loss:  -3.9784
# Total loss:  -2.9271 | PDE Loss:  -3.8796 | Function Loss:  -3.9784
# Total loss:  -2.9271 | PDE Loss:  -3.8795 | Function Loss:  -3.9785
# Total loss:  -2.9271 | PDE Loss:  -3.8792 | Function Loss:  -3.9785
# Total loss:  -2.9272 | PDE Loss:  -3.8787 | Function Loss:  -3.9787
# Total loss:  -2.9272 | PDE Loss:  -3.8779 | Function Loss:  -3.9788
# Total loss:  -2.9273 | PDE Loss:  -3.8773 | Function Loss:  -3.979
# Total loss:  -2.9274 | PDE Loss:  -3.8766 | Function Loss:  -3.9791
# Total loss:  -2.9275 | PDE Loss:  -3.8762 | Function Loss:  -3.9793
# Total loss:  -2.9275 | PDE Loss:  -3.8761 | Function Loss:  -3.9794
# Total loss:  -2.9276 | PDE Loss:  -3.8761 | Function Loss:  -3.9795
# Total loss:  -2.9276 | PDE Loss:  -3.8763 | Function Loss:  -3.9795
# Total loss:  -2.9277 | PDE Loss:  -3.8765 | Function Loss:  -3.9796
# Total loss:  -2.9278 | PDE Loss:  -3.877 | Function Loss:  -3.9796
# Total loss:  -2.9279 | PDE Loss:  -3.8776 | Function Loss:  -3.9797
# Total loss:  -2.9282 | PDE Loss:  -3.8785 | Function Loss:  -3.9798
# Total loss:  -2.9285 | PDE Loss:  -3.8796 | Function Loss:  -3.98
# Total loss:  -2.9289 | PDE Loss:  -3.8809 | Function Loss:  -3.9804
# Total loss:  -2.9296 | PDE Loss:  -3.8826 | Function Loss:  -3.9809
# Total loss:  -2.9303 | PDE Loss:  -3.8822 | Function Loss:  -3.9817
# Total loss:  -2.9309 | PDE Loss:  -3.8837 | Function Loss:  -3.9822
# Total loss:  -2.9318 | PDE Loss:  -3.8865 | Function Loss:  -3.9829
# Total loss:  -2.9327 | PDE Loss:  -3.8897 | Function Loss:  -3.9835
# Total loss:  -2.9336 | PDE Loss:  -3.8916 | Function Loss:  -3.9843
# Total loss:  -2.934 | PDE Loss:  -3.8943 | Function Loss:  -3.9844
# Total loss:  -2.9343 | PDE Loss:  -3.8957 | Function Loss:  -3.9846
# Total loss:  -2.9346 | PDE Loss:  -3.8991 | Function Loss:  -3.9845
# Total loss:  -2.9348 | PDE Loss:  -3.9005 | Function Loss:  -3.9846
# Total loss:  -2.935 | PDE Loss:  -3.9025 | Function Loss:  -3.9845
# Total loss:  -2.9351 | PDE Loss:  -3.9036 | Function Loss:  -3.9845
# Total loss:  -2.9353 | PDE Loss:  -3.905 | Function Loss:  -3.9845
# Total loss:  -2.9354 | PDE Loss:  -3.9061 | Function Loss:  -3.9845
# Total loss:  -2.9355 | PDE Loss:  -3.9071 | Function Loss:  -3.9845
# Total loss:  -2.9355 | PDE Loss:  -3.9076 | Function Loss:  -3.9845
# Total loss:  -2.9355 | PDE Loss:  -3.9079 | Function Loss:  -3.9845
# Total loss:  -2.9356 | PDE Loss:  -3.9083 | Function Loss:  -3.9845
# Total loss:  -2.9356 | PDE Loss:  -3.9084 | Function Loss:  -3.9845
# Total loss:  -2.9356 | PDE Loss:  -3.9086 | Function Loss:  -3.9844
# Total loss:  -2.9356 | PDE Loss:  -3.9087 | Function Loss:  -3.9844
# Total loss:  -2.9356 | PDE Loss:  -3.9088 | Function Loss:  -3.9844
# Total loss:  -2.9356 | PDE Loss:  -3.9088 | Function Loss:  -3.9845
# Total loss:  -2.9356 | PDE Loss:  -3.909 | Function Loss:  -3.9845
# Total loss:  -2.9357 | PDE Loss:  -3.9091 | Function Loss:  -3.9845
# Total loss:  -2.9357 | PDE Loss:  -3.9093 | Function Loss:  -3.9845
# Total loss:  -2.9358 | PDE Loss:  -3.9096 | Function Loss:  -3.9846
# Total loss:  -2.9359 | PDE Loss:  -3.91 | Function Loss:  -3.9847
# Total loss:  -2.9361 | PDE Loss:  -3.9106 | Function Loss:  -3.9848
# Total loss:  -2.9362 | PDE Loss:  -3.9116 | Function Loss:  -3.9848
# Total loss:  -2.9365 | PDE Loss:  -3.9133 | Function Loss:  -3.9849
# Total loss:  -2.9368 | PDE Loss:  -3.9162 | Function Loss:  -3.9849
# Total loss:  -2.9372 | PDE Loss:  -3.9208 | Function Loss:  -3.9848
# Total loss:  -2.9379 | PDE Loss:  -3.9304 | Function Loss:  -3.9845
# Total loss:  -2.9388 | PDE Loss:  -3.9435 | Function Loss:  -3.984
# Total loss:  -2.9397 | PDE Loss:  -3.9599 | Function Loss:  -3.9833
# Total loss:  -2.9407 | PDE Loss:  -3.9769 | Function Loss:  -3.9826
# Total loss:  -2.9414 | PDE Loss:  -3.9875 | Function Loss:  -3.9823
# Total loss:  -2.9414 | PDE Loss:  -3.9992 | Function Loss:  -3.9812
# Total loss:  -2.9419 | PDE Loss:  -3.9977 | Function Loss:  -3.9819
# Total loss:  -2.9423 | PDE Loss:  -4.0017 | Function Loss:  -3.9819
# Total loss:  -2.9427 | PDE Loss:  -4.0062 | Function Loss:  -3.9819
# Total loss:  -2.9429 | PDE Loss:  -4.0093 | Function Loss:  -3.9818
# Total loss:  -2.9431 | PDE Loss:  -4.0115 | Function Loss:  -3.9819
# Total loss:  -2.9433 | PDE Loss:  -4.0151 | Function Loss:  -3.9818
# Total loss:  -2.9435 | PDE Loss:  -4.0164 | Function Loss:  -3.9818
# Total loss:  -2.9436 | PDE Loss:  -4.0186 | Function Loss:  -3.9818
# Total loss:  -2.9438 | PDE Loss:  -4.0187 | Function Loss:  -3.9819
# Total loss:  -2.9438 | PDE Loss:  -4.0198 | Function Loss:  -3.9819
# Total loss:  -2.944 | PDE Loss:  -4.0212 | Function Loss:  -3.9819
# Total loss:  -2.9441 | PDE Loss:  -4.0231 | Function Loss:  -3.9819
# Total loss:  -2.9442 | PDE Loss:  -4.025 | Function Loss:  -3.9819
# Total loss:  -2.9443 | PDE Loss:  -4.0268 | Function Loss:  -3.9818
# Total loss:  -2.9444 | PDE Loss:  -4.0281 | Function Loss:  -3.9818
# Total loss:  -2.9445 | PDE Loss:  -4.0295 | Function Loss:  -3.9817
# Total loss:  -2.9446 | PDE Loss:  -4.0315 | Function Loss:  -3.9816
# Total loss:  -2.9447 | PDE Loss:  -4.0331 | Function Loss:  -3.9816
# Total loss:  -2.9448 | PDE Loss:  -4.0346 | Function Loss:  -3.9816
# Total loss:  -2.9449 | PDE Loss:  -4.0359 | Function Loss:  -3.9816
# Total loss:  -2.945 | PDE Loss:  -4.0371 | Function Loss:  -3.9816
# Total loss:  -2.9451 | PDE Loss:  -4.0384 | Function Loss:  -3.9817
# Total loss:  -2.9453 | PDE Loss:  -4.0394 | Function Loss:  -3.9818
# Total loss:  -2.9455 | PDE Loss:  -4.041 | Function Loss:  -3.9819
# Total loss:  -2.9459 | PDE Loss:  -4.0415 | Function Loss:  -3.9822
# Total loss:  -2.9462 | PDE Loss:  -4.0437 | Function Loss:  -3.9824
# Total loss:  -2.9467 | PDE Loss:  -4.0465 | Function Loss:  -3.9826
# Total loss:  -2.9469 | PDE Loss:  -4.048 | Function Loss:  -3.9828
# Total loss:  -2.9473 | PDE Loss:  -4.05 | Function Loss:  -3.983
# Total loss:  -2.9474 | PDE Loss:  -4.0513 | Function Loss:  -3.9831
# Total loss:  -2.9478 | PDE Loss:  -4.0534 | Function Loss:  -3.9832
# Total loss:  -2.9481 | PDE Loss:  -4.0553 | Function Loss:  -3.9834
# Total loss:  -2.9484 | PDE Loss:  -4.0582 | Function Loss:  -3.9835
# Total loss:  -2.9487 | PDE Loss:  -4.06 | Function Loss:  -3.9837
# Total loss:  -2.9491 | PDE Loss:  -4.0632 | Function Loss:  -3.9838
# Total loss:  -2.9494 | PDE Loss:  -4.0644 | Function Loss:  -3.9841
# Total loss:  -2.9498 | PDE Loss:  -4.0666 | Function Loss:  -3.9843
# Total loss:  -2.95 | PDE Loss:  -4.0671 | Function Loss:  -3.9845
# Total loss:  -2.9503 | PDE Loss:  -4.0683 | Function Loss:  -3.9847
# Total loss:  -2.9507 | PDE Loss:  -4.0701 | Function Loss:  -3.985
# Total loss:  -2.9511 | PDE Loss:  -4.072 | Function Loss:  -3.9853
# Total loss:  -2.9516 | PDE Loss:  -4.0748 | Function Loss:  -3.9855
# Total loss:  -2.952 | PDE Loss:  -4.0753 | Function Loss:  -3.986
# Total loss:  -2.9525 | PDE Loss:  -4.0783 | Function Loss:  -3.9863
# Total loss:  -2.9526 | PDE Loss:  -4.0764 | Function Loss:  -3.9865
# Total loss:  -2.9533 | PDE Loss:  -4.0791 | Function Loss:  -3.9871
# Total loss:  -2.9536 | PDE Loss:  -4.0807 | Function Loss:  -3.9873
# Total loss:  -2.9542 | PDE Loss:  -4.0854 | Function Loss:  -3.9875
# Total loss:  -2.955 | PDE Loss:  -4.0915 | Function Loss:  -3.9879
# Total loss:  -2.9557 | PDE Loss:  -4.0989 | Function Loss:  -3.9881
# Total loss:  -2.9563 | PDE Loss:  -4.1027 | Function Loss:  -3.9884
# Total loss:  -2.9569 | PDE Loss:  -4.1068 | Function Loss:  -3.9888
# Total loss:  -2.9576 | PDE Loss:  -4.1102 | Function Loss:  -3.9893
# Total loss:  -2.9581 | PDE Loss:  -4.1132 | Function Loss:  -3.9896
# Total loss:  -2.9585 | PDE Loss:  -4.1178 | Function Loss:  -3.9896
# Total loss:  -2.9588 | PDE Loss:  -4.1194 | Function Loss:  -3.9899
# Total loss:  -2.959 | PDE Loss:  -4.1205 | Function Loss:  -3.99
# Total loss:  -2.9592 | PDE Loss:  -4.1225 | Function Loss:  -3.9901
# Total loss:  -2.9594 | PDE Loss:  -4.1233 | Function Loss:  -3.9902
# Total loss:  -2.9595 | PDE Loss:  -4.1243 | Function Loss:  -3.9903
# Total loss:  -2.9596 | PDE Loss:  -4.1242 | Function Loss:  -3.9904
# Total loss:  -2.9596 | PDE Loss:  -4.1247 | Function Loss:  -3.9904
# Total loss:  -2.9597 | PDE Loss:  -4.1247 | Function Loss:  -3.9905
# Total loss:  -2.9598 | PDE Loss:  -4.1257 | Function Loss:  -3.9905
# Total loss:  -2.9599 | PDE Loss:  -4.1261 | Function Loss:  -3.9906
# Total loss:  -2.9599 | PDE Loss:  -4.1264 | Function Loss:  -3.9906
# Total loss:  -2.96 | PDE Loss:  -4.127 | Function Loss:  -3.9907
# Total loss:  -2.9601 | PDE Loss:  -4.1273 | Function Loss:  -3.9907
# Total loss:  -2.9603 | PDE Loss:  -4.1274 | Function Loss:  -3.9909
# Total loss:  -2.9605 | PDE Loss:  -4.1297 | Function Loss:  -3.9909
# Total loss:  -2.9607 | PDE Loss:  -4.1295 | Function Loss:  -3.9912
# Total loss:  -2.961 | PDE Loss:  -4.131 | Function Loss:  -3.9914
# Total loss:  -2.9613 | PDE Loss:  -4.1303 | Function Loss:  -3.9918
# Total loss:  -2.9618 | PDE Loss:  -4.1331 | Function Loss:  -3.9921
# Total loss:  -2.9621 | PDE Loss:  -4.1361 | Function Loss:  -3.9922
# Total loss:  -2.9624 | PDE Loss:  -4.1383 | Function Loss:  -3.9924
# Total loss:  -2.9626 | PDE Loss:  -4.1403 | Function Loss:  -3.9925
# Total loss:  -2.9628 | PDE Loss:  -4.1422 | Function Loss:  -3.9925
# Total loss:  -2.9629 | PDE Loss:  -4.1427 | Function Loss:  -3.9926
# Total loss:  -2.963 | PDE Loss:  -4.1419 | Function Loss:  -3.9927
# Total loss:  -2.9631 | PDE Loss:  -4.1441 | Function Loss:  -3.9927
# Total loss:  -2.9632 | PDE Loss:  -4.1447 | Function Loss:  -3.9928
# Total loss:  -2.9633 | PDE Loss:  -4.1443 | Function Loss:  -3.9929
# Total loss:  -2.9634 | PDE Loss:  -4.1444 | Function Loss:  -3.9931
# Total loss:  -2.9635 | PDE Loss:  -4.1439 | Function Loss:  -3.9932
# Total loss:  -2.9636 | PDE Loss:  -4.143 | Function Loss:  -3.9933
# Total loss:  -2.9637 | PDE Loss:  -4.1421 | Function Loss:  -3.9935
# Total loss:  -2.9638 | PDE Loss:  -4.1412 | Function Loss:  -3.9936
# Total loss:  -2.9638 | PDE Loss:  -4.1407 | Function Loss:  -3.9937
# Total loss:  -2.9638 | PDE Loss:  -4.1404 | Function Loss:  -3.9938
# Total loss:  -2.9639 | PDE Loss:  -4.1405 | Function Loss:  -3.9938
# Total loss:  -2.9639 | PDE Loss:  -4.1405 | Function Loss:  -3.9938
# Total loss:  -2.9639 | PDE Loss:  -4.1404 | Function Loss:  -3.9939
# Total loss:  -2.964 | PDE Loss:  -4.1403 | Function Loss:  -3.9939
# Total loss:  -2.964 | PDE Loss:  -4.1402 | Function Loss:  -3.994
# Total loss:  -2.9641 | PDE Loss:  -4.1405 | Function Loss:  -3.994
# Total loss:  -2.9641 | PDE Loss:  -4.1398 | Function Loss:  -3.9941
# Total loss:  -2.9641 | PDE Loss:  -4.1404 | Function Loss:  -3.9941
# Total loss:  -2.9642 | PDE Loss:  -4.141 | Function Loss:  -3.9941
# Total loss:  -2.9642 | PDE Loss:  -4.1414 | Function Loss:  -3.9941
# Total loss:  -2.9642 | PDE Loss:  -4.1422 | Function Loss:  -3.9941
# Total loss:  -2.9643 | PDE Loss:  -4.1431 | Function Loss:  -3.994
# Total loss:  -2.9643 | PDE Loss:  -4.1441 | Function Loss:  -3.994
# Total loss:  -2.9644 | PDE Loss:  -4.1454 | Function Loss:  -3.994
# Total loss:  -2.9644 | PDE Loss:  -4.1461 | Function Loss:  -3.994
# Total loss:  -2.9644 | PDE Loss:  -4.147 | Function Loss:  -3.9939
# Total loss:  -2.9645 | PDE Loss:  -4.1475 | Function Loss:  -3.9939
# Total loss:  -2.9645 | PDE Loss:  -4.1478 | Function Loss:  -3.994
# Total loss:  -2.9645 | PDE Loss:  -4.1483 | Function Loss:  -3.994
# Total loss:  -2.9646 | PDE Loss:  -4.1483 | Function Loss:  -3.994
# Total loss:  -2.9647 | PDE Loss:  -4.1482 | Function Loss:  -3.9941
# Total loss:  -2.9647 | PDE Loss:  -4.1476 | Function Loss:  -3.9942
# Total loss:  -2.9648 | PDE Loss:  -4.147 | Function Loss:  -3.9944
# Total loss:  -2.9649 | PDE Loss:  -4.1462 | Function Loss:  -3.9945
# Total loss:  -2.965 | PDE Loss:  -4.1455 | Function Loss:  -3.9946
# Total loss:  -2.9651 | PDE Loss:  -4.1451 | Function Loss:  -3.9948
# Total loss:  -2.9652 | PDE Loss:  -4.1448 | Function Loss:  -3.9949
# Total loss:  -2.9654 | PDE Loss:  -4.1446 | Function Loss:  -3.9951
# Total loss:  -2.9655 | PDE Loss:  -4.1454 | Function Loss:  -3.9952
# Total loss:  -2.9657 | PDE Loss:  -4.1469 | Function Loss:  -3.9952
# Total loss:  -2.9659 | PDE Loss:  -4.1491 | Function Loss:  -3.9954
# Total loss:  -2.9662 | PDE Loss:  -4.151 | Function Loss:  -3.9955
# Total loss:  -2.9664 | PDE Loss:  -4.1531 | Function Loss:  -3.9957
# Total loss:  -2.9667 | PDE Loss:  -4.1544 | Function Loss:  -3.9959
# Total loss:  -2.9672 | PDE Loss:  -4.1581 | Function Loss:  -3.9961
# Total loss:  -2.9676 | PDE Loss:  -4.1607 | Function Loss:  -3.9963
# Total loss:  -2.9679 | PDE Loss:  -4.1654 | Function Loss:  -3.9964
# Total loss:  -2.9682 | PDE Loss:  -4.1692 | Function Loss:  -3.9965
# Total loss:  -2.9686 | PDE Loss:  -4.1764 | Function Loss:  -3.9964
# Total loss:  -2.9688 | PDE Loss:  -4.1802 | Function Loss:  -3.9963
# Total loss:  -2.969 | PDE Loss:  -4.1865 | Function Loss:  -3.9962
# Total loss:  -2.9693 | PDE Loss:  -4.193 | Function Loss:  -3.996
# Total loss:  -2.9695 | PDE Loss:  -4.1992 | Function Loss:  -3.9958
# Total loss:  -2.9696 | PDE Loss:  -4.203 | Function Loss:  -3.9957
# Total loss:  -2.9697 | PDE Loss:  -4.2054 | Function Loss:  -3.9957
# Total loss:  -2.9697 | PDE Loss:  -4.2061 | Function Loss:  -3.9957
# Total loss:  -2.9699 | PDE Loss:  -4.2086 | Function Loss:  -3.9957
# Total loss:  -2.9699 | PDE Loss:  -4.2085 | Function Loss:  -3.9957
# Total loss:  -2.9701 | PDE Loss:  -4.2074 | Function Loss:  -3.996
# Total loss:  -2.9702 | PDE Loss:  -4.206 | Function Loss:  -3.9962
# Total loss:  -2.9703 | PDE Loss:  -4.2049 | Function Loss:  -3.9964
# Total loss:  -2.9705 | PDE Loss:  -4.2041 | Function Loss:  -3.9966
# Total loss:  -2.9706 | PDE Loss:  -4.2046 | Function Loss:  -3.9967
# Total loss:  -2.9708 | PDE Loss:  -4.207 | Function Loss:  -3.9968
# Total loss:  -2.9711 | PDE Loss:  -4.2113 | Function Loss:  -3.9969
# Total loss:  -2.9714 | PDE Loss:  -4.217 | Function Loss:  -3.9968
# Total loss:  -2.9717 | PDE Loss:  -4.2232 | Function Loss:  -3.9968
# Total loss:  -2.972 | PDE Loss:  -4.2296 | Function Loss:  -3.9967
# Total loss:  -2.9722 | PDE Loss:  -4.2351 | Function Loss:  -3.9966
# Total loss:  -2.9724 | PDE Loss:  -4.2405 | Function Loss:  -3.9964
# Total loss:  -2.9724 | PDE Loss:  -4.2423 | Function Loss:  -3.9964
# Total loss:  -2.9725 | PDE Loss:  -4.2443 | Function Loss:  -3.9964
# Total loss:  -2.9726 | PDE Loss:  -4.2451 | Function Loss:  -3.9964
# Total loss:  -2.9726 | PDE Loss:  -4.245 | Function Loss:  -3.9965
# Total loss:  -2.9727 | PDE Loss:  -4.2453 | Function Loss:  -3.9965
# Total loss:  -2.9727 | PDE Loss:  -4.2456 | Function Loss:  -3.9965
# Total loss:  -2.9728 | PDE Loss:  -4.2465 | Function Loss:  -3.9965
# Total loss:  -2.9728 | PDE Loss:  -4.2477 | Function Loss:  -3.9965
# Total loss:  -2.9728 | PDE Loss:  -4.2492 | Function Loss:  -3.9965
# Total loss:  -2.9729 | PDE Loss:  -4.251 | Function Loss:  -3.9964
# Total loss:  -2.9729 | PDE Loss:  -4.2531 | Function Loss:  -3.9963
# Total loss:  -2.973 | PDE Loss:  -4.2551 | Function Loss:  -3.9963
# Total loss:  -2.973 | PDE Loss:  -4.2576 | Function Loss:  -3.9962
# Total loss:  -2.9731 | PDE Loss:  -4.26 | Function Loss:  -3.9961
# Total loss:  -2.9732 | PDE Loss:  -4.2621 | Function Loss:  -3.9961
# Total loss:  -2.9733 | PDE Loss:  -4.2642 | Function Loss:  -3.9961
# Total loss:  -2.9734 | PDE Loss:  -4.2667 | Function Loss:  -3.9961
# Total loss:  -2.9734 | PDE Loss:  -4.2654 | Function Loss:  -3.9962
# Total loss:  -2.9735 | PDE Loss:  -4.2676 | Function Loss:  -3.9962
# Total loss:  -2.9736 | PDE Loss:  -4.2693 | Function Loss:  -3.9962
# Total loss:  -2.9737 | PDE Loss:  -4.2709 | Function Loss:  -3.9962
# Total loss:  -2.9738 | PDE Loss:  -4.2725 | Function Loss:  -3.9962
# Total loss:  -2.9739 | PDE Loss:  -4.2743 | Function Loss:  -3.9962
# Total loss:  -2.9739 | PDE Loss:  -4.2762 | Function Loss:  -3.9961
# Total loss:  -2.974 | PDE Loss:  -4.2781 | Function Loss:  -3.9961
# Total loss:  -2.974 | PDE Loss:  -4.2798 | Function Loss:  -3.996
# Total loss:  -2.9741 | PDE Loss:  -4.2812 | Function Loss:  -3.996
# Total loss:  -2.9741 | PDE Loss:  -4.2821 | Function Loss:  -3.996
# Total loss:  -2.9741 | PDE Loss:  -4.2825 | Function Loss:  -3.996
# Total loss:  -2.9741 | PDE Loss:  -4.2827 | Function Loss:  -3.996
# Total loss:  -2.9741 | PDE Loss:  -4.2826 | Function Loss:  -3.996
# Total loss:  -2.9742 | PDE Loss:  -4.2826 | Function Loss:  -3.996
# Total loss:  -2.9742 | PDE Loss:  -4.2826 | Function Loss:  -3.9961
# Total loss:  -2.9742 | PDE Loss:  -4.2829 | Function Loss:  -3.9961
# Total loss:  -2.9742 | PDE Loss:  -4.283 | Function Loss:  -3.9961
# Total loss:  -2.9743 | PDE Loss:  -4.2843 | Function Loss:  -3.9961
# ...
# Total loss:  -2.9821 | PDE Loss:  -4.4193 | Function Loss:  -3.9982
# Total loss:  -2.9821 | PDE Loss:  -4.4193 | Function Loss:  -3.9982
# Total loss:  -2.9821 | PDE Loss:  -4.4194 | Function Loss:  -3.9983
# Total loss:  -2.9821 | PDE Loss:  -4.4194 | Function Loss:  -3.9983
# Total loss:  -2.9821 | PDE Loss:  -4.4194 | Function Loss:  -3.9983
# Total loss:  -2.9822 | PDE Loss:  -4.4192 | Function Loss:  -3.9983
# Total loss:  -2.9822 | PDE Loss:  -4.419 | Function Loss:  -3.9984
# Total loss:  -2.9822 | PDE Loss:  -4.4189 | Function Loss:  -3.9984
# Total loss:  -2.9822 | PDE Loss:  -4.4184 | Function Loss:  -3.9984
# Total loss:  -2.9822 | PDE Loss:  -4.4185 | Function Loss:  -3.9984
# Total loss:  -2.9823 | PDE Loss:  -4.4188 | Function Loss:  -3.9985
# Total loss:  -2.9823 | PDE Loss:  -4.4191 | Function Loss:  -3.9985
# Total loss:  -2.9823 | PDE Loss:  -4.42 | Function Loss:  -3.9985
# Total loss:  -2.9823 | PDE Loss:  -4.421 | Function Loss:  -3.9985
# Total loss:  -2.9824 | PDE Loss:  -4.4226 | Function Loss:  -3.9984
# Total loss:  -2.9824 | PDE Loss:  -4.424 | Function Loss:  -3.9984
# Total loss:  -2.9825 | PDE Loss:  -4.4256 | Function Loss:  -3.9984
# Total loss:  -2.9825 | PDE Loss:  -4.4271 | Function Loss:  -3.9984
# Total loss:  -2.9825 | PDE Loss:  -4.4287 | Function Loss:  -3.9984
# Total loss:  -2.9826 | PDE Loss:  -4.4296 | Function Loss:  -3.9984
# Total loss:  -2.9826 | PDE Loss:  -4.4303 | Function Loss:  -3.9984
# Total loss:  -2.9826 | PDE Loss:  -4.4308 | Function Loss:  -3.9984
# Total loss:  -2.9826 | PDE Loss:  -4.4313 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4315 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4322 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4322 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4323 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4325 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4329 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4332 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4335 | Function Loss:  -3.9984
# Total loss:  -2.9827 | PDE Loss:  -4.4339 | Function Loss:  -3.9984
# Total loss:  -2.9828 | PDE Loss:  -4.4343 | Function Loss:  -3.9984
# Total loss:  -2.9828 | PDE Loss:  -4.4348 | Function Loss:  -3.9984
# Total loss:  -2.9829 | PDE Loss:  -4.4353 | Function Loss:  -3.9985
# Total loss:  -2.9829 | PDE Loss:  -4.4364 | Function Loss:  -3.9985
# Total loss:  -2.983 | PDE Loss:  -4.438 | Function Loss:  -3.9986
# Total loss:  -2.9831 | PDE Loss:  -4.44 | Function Loss:  -3.9986
# Total loss:  -2.9832 | PDE Loss:  -4.4418 | Function Loss:  -3.9986
# Total loss:  -2.9833 | PDE Loss:  -4.4441 | Function Loss:  -3.9986
# Total loss:  -2.9834 | PDE Loss:  -4.4469 | Function Loss:  -3.9986
# Total loss:  -2.9835 | PDE Loss:  -4.4512 | Function Loss:  -3.9986
# Total loss:  -2.9836 | PDE Loss:  -4.4546 | Function Loss:  -3.9985
# Total loss:  -2.9836 | PDE Loss:  -4.4578 | Function Loss:  -3.9985
# Total loss:  -2.9837 | PDE Loss:  -4.4601 | Function Loss:  -3.9984
# Total loss:  -2.9837 | PDE Loss:  -4.4617 | Function Loss:  -3.9984
# Total loss:  -2.9837 | PDE Loss:  -4.4627 | Function Loss:  -3.9984
# Total loss:  -2.9838 | PDE Loss:  -4.4636 | Function Loss:  -3.9984
# Total loss:  -2.9838 | PDE Loss:  -4.4646 | Function Loss:  -3.9984
# Total loss:  -2.9839 | PDE Loss:  -4.4653 | Function Loss:  -3.9984
# Total loss:  -2.9839 | PDE Loss:  -4.4663 | Function Loss:  -3.9984
# Total loss:  -2.984 | PDE Loss:  -4.4671 | Function Loss:  -3.9985
# Total loss:  -2.984 | PDE Loss:  -4.4685 | Function Loss:  -3.9985
# Total loss:  -2.984 | PDE Loss:  -4.4699 | Function Loss:  -3.9985
# Total loss:  -2.9841 | PDE Loss:  -4.4713 | Function Loss:  -3.9985
# Total loss:  -2.9841 | PDE Loss:  -4.4732 | Function Loss:  -3.9984
# Total loss:  -2.9842 | PDE Loss:  -4.4742 | Function Loss:  -3.9984
# Total loss:  -2.9842 | PDE Loss:  -4.4752 | Function Loss:  -3.9984
# Total loss:  -2.9842 | PDE Loss:  -4.4761 | Function Loss:  -3.9985
# Total loss:  -2.9843 | PDE Loss:  -4.477 | Function Loss:  -3.9985
# Total loss:  -2.9843 | PDE Loss:  -4.4774 | Function Loss:  -3.9985
# Total loss:  -2.9843 | PDE Loss:  -4.4783 | Function Loss:  -3.9985
# Total loss:  -2.9844 | PDE Loss:  -4.4791 | Function Loss:  -3.9985
# Total loss:  -2.9844 | PDE Loss:  -4.4801 | Function Loss:  -3.9985
# Total loss:  -2.9845 | PDE Loss:  -4.4808 | Function Loss:  -3.9986
# Total loss:  -2.9846 | PDE Loss:  -4.4817 | Function Loss:  -3.9986
# Total loss:  -2.9846 | PDE Loss:  -4.4832 | Function Loss:  -3.9986
# Total loss:  -2.9847 | PDE Loss:  -4.4852 | Function Loss:  -3.9986
# Total loss:  -2.9848 | PDE Loss:  -4.488 | Function Loss:  -3.9986
# Total loss:  -2.9849 | PDE Loss:  -4.4909 | Function Loss:  -3.9987
# Total loss:  -2.985 | PDE Loss:  -4.4946 | Function Loss:  -3.9987
# Total loss:  -2.9851 | PDE Loss:  -4.4978 | Function Loss:  -3.9987
# Total loss:  -2.9853 | PDE Loss:  -4.5006 | Function Loss:  -3.9987
# Total loss:  -2.9853 | PDE Loss:  -4.5033 | Function Loss:  -3.9987
# Total loss:  -2.9854 | PDE Loss:  -4.5047 | Function Loss:  -3.9987
# Total loss:  -2.9855 | PDE Loss:  -4.5068 | Function Loss:  -3.9987
# Total loss:  -2.9855 | PDE Loss:  -4.509 | Function Loss:  -3.9987
# Total loss:  -2.9856 | PDE Loss:  -4.5112 | Function Loss:  -3.9987
# Total loss:  -2.9856 | PDE Loss:  -4.5127 | Function Loss:  -3.9987
# Total loss:  -2.9856 | PDE Loss:  -4.5142 | Function Loss:  -3.9987
# Total loss:  -2.9857 | PDE Loss:  -4.5152 | Function Loss:  -3.9987
# Total loss:  -2.9857 | PDE Loss:  -4.5157 | Function Loss:  -3.9988
# Total loss:  -2.9858 | PDE Loss:  -4.5159 | Function Loss:  -3.9988
# Total loss:  -2.9858 | PDE Loss:  -4.5166 | Function Loss:  -3.9988
# Total loss:  -2.9858 | PDE Loss:  -4.5166 | Function Loss:  -3.9988
# Total loss:  -2.9858 | PDE Loss:  -4.5169 | Function Loss:  -3.9988
# Total loss:  -2.9858 | PDE Loss:  -4.5172 | Function Loss:  -3.9988
# Total loss:  -2.9859 | PDE Loss:  -4.5174 | Function Loss:  -3.9988
# Total loss:  -2.9859 | PDE Loss:  -4.5177 | Function Loss:  -3.9988
# Total loss:  -2.9859 | PDE Loss:  -4.5178 | Function Loss:  -3.9988
# Total loss:  -2.9859 | PDE Loss:  -4.5181 | Function Loss:  -3.9988
# Total loss:  -2.9859 | PDE Loss:  -4.5185 | Function Loss:  -3.9988
# Total loss:  -2.9859 | PDE Loss:  -4.5188 | Function Loss:  -3.9988
# Total loss:  -2.9859 | PDE Loss:  -4.5194 | Function Loss:  -3.9988
# Total loss:  -2.986 | PDE Loss:  -4.5199 | Function Loss:  -3.9988
# Total loss:  -2.986 | PDE Loss:  -4.5205 | Function Loss:  -3.9988
# Total loss:  -2.986 | PDE Loss:  -4.521 | Function Loss:  -3.9988
# Total loss:  -2.986 | PDE Loss:  -4.5217 | Function Loss:  -3.9988
# Total loss:  -2.986 | PDE Loss:  -4.5223 | Function Loss:  -3.9988
# Total loss:  -2.986 | PDE Loss:  -4.5227 | Function Loss:  -3.9988
# Total loss:  -2.986 | PDE Loss:  -4.5231 | Function Loss:  -3.9988
# Total loss:  -2.9861 | PDE Loss:  -4.5232 | Function Loss:  -3.9989
# Total loss:  -2.9861 | PDE Loss:  -4.5233 | Function Loss:  -3.9989
# Total loss:  -2.9861 | PDE Loss:  -4.523 | Function Loss:  -3.9989
# Total loss:  -2.9861 | PDE Loss:  -4.5227 | Function Loss:  -3.9989
# Total loss:  -2.9861 | PDE Loss:  -4.5225 | Function Loss:  -3.9989
# Total loss:  -2.9861 | PDE Loss:  -4.522 | Function Loss:  -3.9989
# Total loss:  -2.9861 | PDE Loss:  -4.5215 | Function Loss:  -3.9989
# Total loss:  -2.9861 | PDE Loss:  -4.5209 | Function Loss:  -3.999
# Total loss:  -2.9861 | PDE Loss:  -4.5202 | Function Loss:  -3.999
# Total loss:  -2.9861 | PDE Loss:  -4.5196 | Function Loss:  -3.999
# Total loss:  -2.9861 | PDE Loss:  -4.519 | Function Loss:  -3.999
# Total loss:  -2.9861 | PDE Loss:  -4.5185 | Function Loss:  -3.9991
# Total loss:  -2.9862 | PDE Loss:  -4.5182 | Function Loss:  -3.9991
# Total loss:  -2.9862 | PDE Loss:  -4.5182 | Function Loss:  -3.9991
# Total loss:  -2.9862 | PDE Loss:  -4.5186 | Function Loss:  -3.9991
# Total loss:  -2.9862 | PDE Loss:  -4.5193 | Function Loss:  -3.9991
# Total loss:  -2.9862 | PDE Loss:  -4.5204 | Function Loss:  -3.9991
# Total loss:  -2.9863 | PDE Loss:  -4.5216 | Function Loss:  -3.9991
# Total loss:  -2.9863 | PDE Loss:  -4.5231 | Function Loss:  -3.9991
# Total loss:  -2.9863 | PDE Loss:  -4.5246 | Function Loss:  -3.9991
# Total loss:  -2.9863 | PDE Loss:  -4.5251 | Function Loss:  -3.9991
# Total loss:  -2.9864 | PDE Loss:  -4.5257 | Function Loss:  -3.9991
# Total loss:  -2.9864 | PDE Loss:  -4.5261 | Function Loss:  -3.9991
# Total loss:  -2.9864 | PDE Loss:  -4.5266 | Function Loss:  -3.9991
# Total loss:  -2.9864 | PDE Loss:  -4.5273 | Function Loss:  -3.9991
# Total loss:  -2.9864 | PDE Loss:  -4.5277 | Function Loss:  -3.9991
# Total loss:  -2.9864 | PDE Loss:  -4.5278 | Function Loss:  -3.9991
# Total loss:  -2.9865 | PDE Loss:  -4.528 | Function Loss:  -3.9991
# Total loss:  -2.9865 | PDE Loss:  -4.5277 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5275 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.527 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5268 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5265 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5264 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5262 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5262 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5262 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5263 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5266 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5268 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.527 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5272 | Function Loss:  -3.9992
# Total loss:  -2.9865 | PDE Loss:  -4.5274 | Function Loss:  -3.9992
# Total loss:  -2.9866 | PDE Loss:  -4.5275 | Function Loss:  -3.9992
# Total loss:  -2.9866 | PDE Loss:  -4.528 | Function Loss:  -3.9992
# Total loss:  -2.9866 | PDE Loss:  -4.5281 | Function Loss:  -3.9993
# Total loss:  -2.9866 | PDE Loss:  -4.5282 | Function Loss:  -3.9993
# Total loss:  -2.9866 | PDE Loss:  -4.5285 | Function Loss:  -3.9993
# Total loss:  -2.9866 | PDE Loss:  -4.5291 | Function Loss:  -3.9993
# Total loss:  -2.9867 | PDE Loss:  -4.5295 | Function Loss:  -3.9993
# Total loss:  -2.9867 | PDE Loss:  -4.53 | Function Loss:  -3.9993
# Total loss:  -2.9867 | PDE Loss:  -4.5305 | Function Loss:  -3.9993
# Total loss:  -2.9867 | PDE Loss:  -4.5314 | Function Loss:  -3.9993
# Total loss:  -2.9867 | PDE Loss:  -4.5327 | Function Loss:  -3.9993
# Total loss:  -2.9868 | PDE Loss:  -4.5342 | Function Loss:  -3.9993
# Total loss:  -2.9868 | PDE Loss:  -4.5359 | Function Loss:  -3.9992
# Total loss:  -2.9869 | PDE Loss:  -4.5381 | Function Loss:  -3.9992
# Total loss:  -2.9869 | PDE Loss:  -4.5404 | Function Loss:  -3.9992
# Total loss:  -2.987 | PDE Loss:  -4.5424 | Function Loss:  -3.9992
# Total loss:  -2.9871 | PDE Loss:  -4.5448 | Function Loss:  -3.9993
# Total loss:  -2.9872 | PDE Loss:  -4.5491 | Function Loss:  -3.9993
# Total loss:  -2.9873 | PDE Loss:  -4.5518 | Function Loss:  -3.9993
# Total loss:  -2.9874 | PDE Loss:  -4.5551 | Function Loss:  -3.9993
# Total loss:  -2.9875 | PDE Loss:  -4.5585 | Function Loss:  -3.9993
# Total loss:  -2.9875 | PDE Loss:  -4.5601 | Function Loss:  -3.9993
# Total loss:  -2.9876 | PDE Loss:  -4.5642 | Function Loss:  -3.9993
# Total loss:  -2.9877 | PDE Loss:  -4.5663 | Function Loss:  -3.9993
# Total loss:  -2.9878 | PDE Loss:  -4.5701 | Function Loss:  -3.9994
# Total loss:  -2.988 | PDE Loss:  -4.574 | Function Loss:  -3.9994
# Total loss:  -2.9881 | PDE Loss:  -4.5789 | Function Loss:  -3.9994
# Total loss:  -2.9882 | PDE Loss:  -4.5841 | Function Loss:  -3.9993
# Total loss:  -2.9883 | PDE Loss:  -4.589 | Function Loss:  -3.9993
# Total loss:  -2.9883 | PDE Loss:  -4.5898 | Function Loss:  -3.9993
# Total loss:  -2.9884 | PDE Loss:  -4.592 | Function Loss:  -3.9993
# Total loss:  -2.9884 | PDE Loss:  -4.5937 | Function Loss:  -3.9993
# Total loss:  -2.9885 | PDE Loss:  -4.5969 | Function Loss:  -3.9993
# Total loss:  -2.9885 | PDE Loss:  -4.5997 | Function Loss:  -3.9993
# Total loss:  -2.9886 | PDE Loss:  -4.6048 | Function Loss:  -3.9992
# Total loss:  -2.9887 | PDE Loss:  -4.6081 | Function Loss:  -3.9992
# Total loss:  -2.9888 | PDE Loss:  -4.614 | Function Loss:  -3.9992
# Total loss:  -2.9889 | PDE Loss:  -4.6197 | Function Loss:  -3.9992
# Total loss:  -2.989 | PDE Loss:  -4.624 | Function Loss:  -3.9991
# Total loss:  -2.9891 | PDE Loss:  -4.6302 | Function Loss:  -3.9991
# Total loss:  -2.9891 | PDE Loss:  -4.6338 | Function Loss:  -3.9991
# Total loss:  -2.9892 | PDE Loss:  -4.6406 | Function Loss:  -3.999
# Total loss:  -2.9892 | PDE Loss:  -4.6418 | Function Loss:  -3.999
# Total loss:  -2.9893 | PDE Loss:  -4.6449 | Function Loss:  -3.999
# Total loss:  -2.9893 | PDE Loss:  -4.6471 | Function Loss:  -3.999
# Total loss:  -2.9894 | PDE Loss:  -4.6503 | Function Loss:  -3.999
# Total loss:  -2.9894 | PDE Loss:  -4.6532 | Function Loss:  -3.999
# Total loss:  -2.9895 | PDE Loss:  -4.6559 | Function Loss:  -3.999
# Total loss:  -2.9896 | PDE Loss:  -4.6607 | Function Loss:  -3.999
# Total loss:  -2.9897 | PDE Loss:  -4.6624 | Function Loss:  -3.999
# Total loss:  -2.9897 | PDE Loss:  -4.6659 | Function Loss:  -3.999
# Total loss:  -2.9898 | PDE Loss:  -4.6679 | Function Loss:  -3.999
# Total loss:  -2.9898 | PDE Loss:  -4.6706 | Function Loss:  -3.999
# Total loss:  -2.9899 | PDE Loss:  -4.6731 | Function Loss:  -3.999
# Total loss:  -2.9899 | PDE Loss:  -4.6751 | Function Loss:  -3.999
# Total loss:  -2.99 | PDE Loss:  -4.6775 | Function Loss:  -3.999
# Total loss:  -2.99 | PDE Loss:  -4.6813 | Function Loss:  -3.9989
# Total loss:  -2.99 | PDE Loss:  -4.6825 | Function Loss:  -3.999
# Total loss:  -2.9901 | PDE Loss:  -4.6858 | Function Loss:  -3.9989
# Total loss:  -2.9901 | PDE Loss:  -4.6873 | Function Loss:  -3.9989
# Total loss:  -2.9901 | PDE Loss:  -4.6891 | Function Loss:  -3.9989
# Total loss:  -2.9902 | PDE Loss:  -4.692 | Function Loss:  -3.9989
# Total loss:  -2.9902 | PDE Loss:  -4.6951 | Function Loss:  -3.9989
# Total loss:  -2.9902 | PDE Loss:  -4.6977 | Function Loss:  -3.9988
# Total loss:  -2.9903 | PDE Loss:  -4.7012 | Function Loss:  -3.9988
# Total loss:  -2.9903 | PDE Loss:  -4.702 | Function Loss:  -3.9988
# Total loss:  -2.9904 | PDE Loss:  -4.7042 | Function Loss:  -3.9988
# Total loss:  -2.9904 | PDE Loss:  -4.7051 | Function Loss:  -3.9988
# Total loss:  -2.9904 | PDE Loss:  -4.7065 | Function Loss:  -3.9988
# Total loss:  -2.9904 | PDE Loss:  -4.7078 | Function Loss:  -3.9988
# Total loss:  -2.9904 | PDE Loss:  -4.7089 | Function Loss:  -3.9988
# Total loss:  -2.9905 | PDE Loss:  -4.7107 | Function Loss:  -3.9988
# Total loss:  -2.9905 | PDE Loss:  -4.7116 | Function Loss:  -3.9988
# Total loss:  -2.9905 | PDE Loss:  -4.7123 | Function Loss:  -3.9988
# Total loss:  -2.9905 | PDE Loss:  -4.7132 | Function Loss:  -3.9988
# Total loss:  -2.9905 | PDE Loss:  -4.7139 | Function Loss:  -3.9988
# Total loss:  -2.9906 | PDE Loss:  -4.7144 | Function Loss:  -3.9989
# Total loss:  -2.9906 | PDE Loss:  -4.7144 | Function Loss:  -3.9989
# Total loss:  -2.9906 | PDE Loss:  -4.7146 | Function Loss:  -3.9989
# Total loss:  -2.9906 | PDE Loss:  -4.7139 | Function Loss:  -3.9989
# Total loss:  -2.9907 | PDE Loss:  -4.7141 | Function Loss:  -3.9989
# Total loss:  -2.9907 | PDE Loss:  -4.7145 | Function Loss:  -3.999
# Total loss:  -2.9907 | PDE Loss:  -4.7151 | Function Loss:  -3.999
# Total loss:  -2.9907 | PDE Loss:  -4.7157 | Function Loss:  -3.999
# Total loss:  -2.9907 | PDE Loss:  -4.7165 | Function Loss:  -3.999
# Total loss:  -2.9907 | PDE Loss:  -4.7169 | Function Loss:  -3.999
# Total loss:  -2.9908 | PDE Loss:  -4.7174 | Function Loss:  -3.999
# Total loss:  -2.9908 | PDE Loss:  -4.7184 | Function Loss:  -3.999
# Total loss:  -2.9908 | PDE Loss:  -4.719 | Function Loss:  -3.999
# Total loss:  -2.9908 | PDE Loss:  -4.7199 | Function Loss:  -3.999
# Total loss:  -2.9908 | PDE Loss:  -4.7209 | Function Loss:  -3.999
# Total loss:  -2.9908 | PDE Loss:  -4.722 | Function Loss:  -3.999
# Final Loss:  -2.9908270835876465

# %%
plotting(pinn)
# Out:
# L2 Relative Error Norm U:  0.20409026741981506 %
# L2 Relative Error Norm K:  3.1503398418426514 %
